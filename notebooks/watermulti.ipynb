# %%
import fiona
import requests
import json
import collections
import matplotlib as plt
import geopandas as gpd
import pandas as pd
from shapely.geometry import shape, mapping

# %%
data = '''

{"type": "LineString",
 "coordinates": [[-77.20558556958042, 41.5681402875175],
  [-77.20590194390385, 41.56785366919497],
  [-77.20612818808348, 41.567606007618245],
  [-77.20629833618311, 41.56733695352683],
  [-77.20646340532033, 41.56702137131211],
  [-77.20657744068465, 41.56676361925528],
  [-77.20666088142426, 41.56648825436915],
  [-77.2068208057624, 41.566256921420226],
  [-77.20710318233483, 41.56593256744147],
  [-77.20744846213431, 41.56560445690435],
  [-77.20764742897947, 41.56549007836115],
  [-77.20806579714592, 41.56518587718943],
  [-77.20828010405948, 41.56498222101872],
  [-77.20828010405948, 41.56498222101872]]}

'''


"{'type': 'LineString', 'coordinates': [[(-74.8537632577547, 41.0503028078561), (-74.8536103295425, 41.0503404600062), (-74.8536049375839, 41.0504126549615), (-74.8534397850594, 41.0503256725904), (-74.8534278654486, 41.050257905182), (-74.8534044593262, 41.0502032963436), (-74.8534795080255, 41.0501899428331), (-74.8535052063539, 41.0501329961679), (-74.8535569424212, 41.0500825312938), (-74.8536180368698, 41.0501610839381), (-74.8536068548405, 41.0502311094369), (-74.8537632577547, 41.0503028078561)]]}"

# %%
_url = 'https://watersheds-staging.cci.drexel.edu/api/watershedboundary/'
_headers = {'Content-Type': 'application/json'}
r = requests.post(_url, data = data, headers= _headers, allow_redirects=True, verify=False)
r.text
# Out:
# /opt/conda/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'watersheds-staging.cci.drexel.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
