# %% [markdown]
# ### IO for the Water Temperature API
# 48-Hour temperature predictions for USGS gage 01389005

# %%
from ipyleaflet import Map, basemaps, Polygon, DrawControl, WidgetControl, GeoJSON, MeasureControl, WKTLayer, Popup
from ipywidgets import IntSlider, ColorPicker, jslink, HTML
import sys
import requests
import geojson
import json
import shapely
from shapely.geometry import shape, GeometryCollection
import matplotlib.pyplot as plt
import xmltodict
import pprint
import time
from datetime import datetime

# %%
# LOAD IN THE GAGE DATA
with open('usgs_gages.geojson') as json_file:
    features = json.load(json_file)["features"]
with open('usgs_gages.geojson') as json_file:
    gage_lkup = json.load(json_file)

gages = GeometryCollection([shape(feature["geometry"]) for feature in features])

with open('usgs_gages_wtshds.geojson') as json_file:
    features = json.load(json_file)["features"]

gage_watersheds = GeometryCollection([shape(feature["geometry"]).buffer(0) for feature in features])

# %%
# PICK THE USGS GAGE OR LOCATION THAT YOU WANT MODELED

gage_labels = {'01382170': [gages[0].coords.xy[0][0], gages[0].coords.xy[1][0]],
         '01382210': [gages[1].coords.xy[0][0], gages[1].coords.xy[1][0]],
         '01382310': [gages[2].coords.xy[0][0], gages[2].coords.xy[1][0]],
         '01382381': [gages[3].coords.xy[0][0], gages[3].coords.xy[1][0]], 
         '01382385': [gages[4].coords.xy[0][0], gages[4].coords.xy[1][0]], 
         '01389005': [gages[5].coords.xy[0][0], gages[5].coords.xy[1][0]]}

# Map centred on target watersheds
map_center = (gage_watersheds[5].centroid.coords[0][1], gage_watersheds[5].centroid.coords[0][0])
displaymap1 = Map(center = map_center, zoom = 9, min_zoom = 1, max_zoom = 20,  scroll_wheel_zoom = True,
    basemap=basemaps.Esri.WorldStreetMap)

# Enable drawing points/polygons/lines
draw_control = DrawControl()
draw_control.point =  {
    "shapeOptions": {
        "color": "#6bc2e5",
        "weight": 1,
        "opacity": 1.0
    }
}
draw_control.polyline =  {
    "shapeOptions": {
        "color": "#6bc2e5",
        "weight": 4,
        "opacity": 1.0
    }
}
draw_control.polygon = {
    "shapeOptions": {
        "fillColor": "#6be5c3",
        "color": "#6be5c3",
        "fillOpacity": 0.3
    },
    "drawError": {
        "color": "#dd253b",
        "message": "Oups!"
    },
    "allowIntersection": True
}

watersheds_layer = WKTLayer(
    wkt_string=gage_watersheds.wkt,
    style={
        'opacity': 1, 'dashArray': '2', 'fillOpacity': 0.2, 'weight': 1, 'color': 'blue'
    }
)

gages_layer = WKTLayer(
    wkt_string=gages.wkt,
    label = gage_labels
    
)

# Save the drawn geometry to a geojson
draw_feature_collection = {
    'type': 'FeatureCollection',
    'features': []
}

click_feature_collection = {
    'type': 'FeatureCollection',
    'features': []
}

def handle_draw(self, action, geo_json):
    # Save the GeoJSON when it's drawn on the map  
    draw_feature_collection['features'].append(geo_json)

def handle_click(**kwargs):
    # Save the last clicked point
    click_feature_collection['features'].append(kwargs['feature'])
    x = kwargs['feature']['geometry']['coordinates'][0]
    y = kwargs['feature']['geometry']['coordinates'][1]
    for label, coords in gage_labels.items():
        if gage_labels[label][0] == x and gage_labels[label][1] == y:
            gage = label
            print('Selected USGS Gage Station {} at ({},{})'.format(gage, y, x), end='\r')

gages_layer.on_click(handle_click)

# Add everything into the map
draw_control.on_draw(handle_draw)
displaymap1.add_control(draw_control)
displaymap1.add_layer(gages_layer)
displaymap1.add_layer(watersheds_layer)

displaymap1
# Out:
# Map(center=[40.98064101320725, -74.36654960990295], controls=(ZoomControl(options=['position', 'zoom_in_text',…
# Selected USGS Gage Station 01389005 at (40.89638889000001,-74.2691667)

# %%
# Show the clicked gage
last_geom_idx = len(click_feature_collection['features']) - 1
last_geom = click_feature_collection['features'][last_geom_idx]['geometry']
x = last_geom['coordinates'][0]
y = last_geom['coordinates'][1]
for label, coords in gage_labels.items():
        if gage_labels[label][0] == x and gage_labels[label][1] == y:
            gage = label
print(gage)
last_geom
# Out:
# 01389005
# {'type': 'Point', 'coordinates': [-74.2691667, 40.89638889000001]}

# %%
# GET NWIS DATA for POR of Last 7 Days
nwis_url = 'http://waterservices.usgs.gov/nwis/iv/?sites={}&parameterCd=00010&period=P7D'.format(gage)
#_headers = {'Content-Type': 'application/json'}
_r = requests.post(nwis_url, allow_redirects=True, verify=True)
_r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><ns1:timeSeriesResponse xsi:schemaLocation="http://www.cuahsi.org/waterML/1.1/ http://waterservices.usgs.gov/WaterML-1.1.xsd" xmlns:ns1="http://www.cuahsi.org/waterML/1.1/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><ns1:queryInfo xmlns:ns2="http://www.cuahsi.org/waterML/1.1/"><ns2:queryURL>http://waterservices.usgs.gov/nwis/iv/sites=01389005&amp;parameterCd=00010&amp;period=P7D</ns2:queryURL><ns2:criteria><ns2:locationParam>[ALL:01389005]</ns2:locationParam><ns2:variableParam>[00010]</ns2:variableParam></ns2:criteria><ns2:note title="filter:sites">[ALL:01389005]</ns2:note><ns2:note title="filter:timeRange">[mode=PERIOD, period=P7D, modifiedSince=null]</ns2:note><ns2:note title="filter:methodId">methodIds=[ALL]</ns2:note><ns2:note title="requestDT">2021-04-21T15:43:16.477Z</ns2:note><ns2:note title="requestId">4a09a3c0-a2b8-11eb-8a3c-2cea7f5e5ede</ns2:note><ns2:note title="disclaimer">Provisional data are subject to revision. Go to http://waterdata.usgs.gov/nwis/help/?provisional for more information.</ns2:note><ns2:note title="server">sdas01</ns2:note></ns1:queryInfo><ns1:timeSeries name="USGS:01389005:00010:00000" xmlns:ns1="http://www.cuahsi.org/waterML/1.1/"><ns1:sourceInfo xsi:type="ns1:SiteInfoType" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><ns1:siteName>Passaic River below Pompton Riv at Two Bridges NJ</ns1:siteName><ns1:siteCode network="NWIS" agencyCode="USGS">01389005</ns1:siteCode><ns1:timeZoneInfo siteUsesDaylightSavingsTime="true"><ns1:defaultTimeZone zoneOffset="-05:00" zoneAbbreviation="EST"/><ns1:daylightSavingsTimeZone zoneOffset="-04:00" zoneAbbreviation="EDT"/></ns1:timeZoneInfo><ns1:geoLocation><ns1:geogLocation xsi:type="ns1:LatLonPointType" srs="EPSG:4326"><ns1:latitude>40.89638889</ns1:latitude><ns1:longitude>-74.2691667</ns1:longitude></ns1:geogLocation></ns1:geoLocation><ns1:siteProperty name="siteTypeCd">ST</ns1:siteProperty><ns1:siteProperty name="hucCd">02030103</ns1:siteProperty><ns1:siteProperty name="stateCd">34</ns1:siteProperty><ns1:siteProperty name="countyCd">34031</ns1:siteProperty></ns1:sourceInfo><ns1:variable ns1:oid="45807042"><ns1:variableCode network="NWIS" vocabulary="NWIS:UnitValues" default="true" variableID="45807042">00010</ns1:variableCode><ns1:variableName>Temperature, water, &amp;#176;C</ns1:variableName><ns1:variableDescription>Temperature, water, degrees Celsius</ns1:variableDescription><ns1:valueType>Derived Value</ns1:valueType><ns1:unit><ns1:unitCode>deg C</ns1:unitCode></ns1:unit><ns1:options><ns1:option name="Statistic" optionCode="00000"/></ns1:options><ns1:noDataValue>-999999.0</ns1:noDataValue></ns1:variable><ns1:values><ns1:value qualifiers="P" dateTime="2021-04-14T12:00:00.000-04:00">13.3</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T13:00:00.000-04:00">13.6</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T14:00:00.000-04:00">13.7</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T15:00:00.000-04:00">13.8</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T16:00:00.000-04:00">13.9</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T17:00:00.000-04:00">14.0</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T18:00:00.000-04:00">14.0</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T19:00:00.000-04:00">14.0</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T20:00:00.000-04:00">13.9</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T21:00:00.000-04:00">13.8</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T22:00:00.000-04:00">13.8</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-14T23:00:00.000-04:00">13.6</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-15T00:00:00.000-04:00">13.6</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-15T01:00:00.000-04:00">13.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-15T02:00:00.000-04:00">13.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-15T03: ...

# %%
test1 = eval(json.dumps(xmltodict.parse(_r.text)))
wt_ts_raw = test1['ns1:timeSeriesResponse']['ns1:timeSeries']['ns1:values']
wt_ts_raw[0]['ns1:value'][0]
# Out:
# {'@qualifiers': 'P',
#  '@dateTime': '2021-04-14T12:00:00.000-04:00',
#  '#text': '13.3'}

# %%
# FOR GAGES WITH MULTIPLE INTAKES (RIGHT, CENTER, LEFT), WE NEED TO AVERAGE ALL OF THEM TOGETHER
wt_ts = {}
for i in range(0, len(wt_ts_raw)):
    for j in range(0,len(wt_ts_raw[i]['ns1:value']) - 1):
        if str(wt_ts_raw[i]['ns1:value'][j]['@dateTime']) in wt_ts.keys():
            wt_ts[str(wt_ts_raw[i]['ns1:value'][j]['@dateTime'])] += float(wt_ts_raw[i]['ns1:value'][j]['#text'])
        else:
            wt_ts[str(wt_ts_raw[i]['ns1:value'][j]['@dateTime'])] = float(wt_ts_raw[i]['ns1:value'][j]['#text'])

for i in wt_ts:
        wt_ts[i] = float(wt_ts[i]/len(wt_ts_raw))

wt_ts
# Out:
# {'2021-04-14T12:00:00.000-04:00': 13.366666666666667,
#  '2021-04-14T13:00:00.000-04:00': 13.5,
#  '2021-04-14T14:00:00.000-04:00': 13.533333333333333,
#  '2021-04-14T15:00:00.000-04:00': 13.6,
#  '2021-04-14T16:00:00.000-04:00': 13.700000000000001,
#  '2021-04-14T17:00:00.000-04:00': 13.733333333333334,
#  '2021-04-20T22:00:00.000-04:00': 14.133333333333335,
#  '2021-04-20T23:00:00.000-04:00': 14.133333333333335,
#  '2021-04-21T00:00:00.000-04:00': 14.133333333333335,
#  '2021-04-21T01:00:00.000-04:00': 14.066666666666668,
#  '2021-04-21T02:00:00.000-04:00': 14.1,
#  '2021-04-21T03:00:00.000-04:00': 13.966666666666667,
#  '2021-04-21T04:00:00.000-04:00': 13.866666666666667,
#  '2021-04-21T05:00:00.000-04:00': 13.799999999999999,
#  '2021-04-21T06:00:00.000-04:00': 13.733333333333334,
#  '2021-04-21T07:00:00.000-04:00': 13.666666666666666,
#  '2021-04-21T08:00:00.000-04:00': 13.666666666666666,
#  '2021-04-21T09:00:00.000-04:00': 13.733333333333334,
#  '2021-04-21T10:00:00.000-04:00': 13.866666666666667}

# %%
# SET UP TIME VARIABLES FOR WEATHER DATA
now_ep = int(time.time())
now_dt = datetime.now()
seconds_since_midnight = int((now_dt - now_dt.replace(hour=0, minute=0, second=0, microsecond=0)).total_seconds()) - 3600
day = 60*60*24
week = day * 7
last_week = now_ep - seconds_since_midnight - week

# %%
# GET LAST WEEK OF METEOROLOGICAL DATA

'''
Dark Sky is Best for Historical Data, however we cannot get new API keys so we might want to use a different service

API FORMATTING
"https://api.darksky.net/forecast/{}/{},{},{}".format([key], [latitude], [longitude], [time])

Gives daily min, max and hourly temperatures.
- sunrise/sunset
- precipitation intensity, probability, and type
- dewpoint, humidity, pressure, wind speed, visibility
- cloud cover (0-1), uvIndex, ozone
- nearest station
'''

locationt = (y, x)
ds_key = '1c78f26704537fe8484c246658d49fe1'

weather_arr = []
time_curr = last_week
for i in range(0,8):
    urlt = "https://api.darksky.net/forecast/{}/{},{},{}?exclude=currently,minutely,daily,flags,alerts".format(ds_key, locationt[0], locationt[1], time_curr)
    time_curr += day
    response = requests.request("GET", urlt)#, headers=headers)
    dt = eval(response.text)
    weather_arr.append(dt)

weather_arr
# Out:
# [{'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'data': [{'time': 1618372800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.78,
#      'apparentTemperature': 51.78,
#      'dewPoint': 44.07,
#      'humidity': 0.75,
#      'pressure': 1018.2,
#      'windSpeed': 1.7,
#      'windGust': 6.65,
#      'windBearing': 156,
#      'cloudCover': 0.29,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 348.9},
#     {'time': 1618376400,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.66,
#      'apparentTemperature': 50.66,
#      'dewPoint': 44.11,
#      'humidity': 0.78,
#      'pressure': 1018.2,
#      'windSpeed': 1.83,
#      'windGust': 6.04,
#      'windBearing': 148,
#      'cloudCover': 0.34,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 349.6},
#     {'time': 1618380000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.95,
#      'apparentTemperature': 47.95,
#      'dewPoint': 43.55,
#      'humidity': 0.85,
#      'pressure': 1018.1,
#      'windSpeed': 1.57,
#      'windGust': 4.2,
#      'windBearing': 138,
#      'cloudCover': 0.17,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 351.4},
#     {'time': 1618383600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.38,
#      'apparentTemperature': 46.38,
#      'dewPoint': 42.85,
#      'humidity': 0.87,
#      'pressure': 1018.1,
#      'windSpeed': 1.28,
#      'windGust': 3.17,
#      'windBearing': 283,
#      'cloudCover': 0.15,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 349.7},
#     {'time': 1618387200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.98,
#      'apparentTemperature': 44.98,
#      'dewPoint': 43.32,
#      'humidity': 0.94,
#      'pressure': 1018.2,
#      'windSpeed': 1.62,
#      'windGust': 3.59,
#      'windBearing': 89,
#      'cloudCover': 0.15,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 346.9},
#     {'time': 1618390800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.57,
#      'apparentTemperature': 44.57,
#      'dewPoint': 41.48,
#      'humidity': 0.89,
#      'pressure': 1018,
#      'windSpeed': 1.19,
#      'windGust': 3.62,
#      'windBearing': 240,
#      'cloudCover': 0.16,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 346.5},
#     {'time': 1618394400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0.0037,
#      'precipProbability': 0.01,
#      'precipType': 'rain',
#      'temperature': 44.15,
#      'apparentTemperature': 44.15,
#      'dewPoint': 40.62,
#      'humidity': 0.87,
#      'pressure': 1018.2,
#      'windSpeed': 1.19,
#      'windGust': 3.18,
#      'windBearing': 206,
#      'cloudCover': 0.12,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 346.9},
#     {'time': 1618398000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.14,
#      'apparentTemperature': 44.14,
#      'dewPoint': 41.27,
#      'humidity': 0.9,
#      'pressure': 1018.4,
#      'windSpeed': 1.13,
#      'windGust': 3.76,
#      'windBearing': 311,
#      'cloudCover': 0.22,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 347.9},
#     {'time': 1618401600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.69,
#      'apparentTemperature': 48.69,
#      'dewPoint': 44.28,
#      'humidity': 0.85,
#      'pressure': 1018.5,
#      'windSpeed': 1.25,
#      'windGust': 5.78,
#      'windBearing': 302,
#      'cloudCover': 0.1,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 344},
#     {'time': 1618405200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.29,
#      'apparentTemperature': 54.29,
#      'dewPoint': 44.84,
#      'humidity': 0.7,
#      'pressure': 1018,
#      'windSpeed': 1.2,
#      'windGust': 5.86,
#      'windBearing': 353,
#      'cloudCover': 0.14,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 346.8},
#     {'time': 1618408800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.5,
#      'apparentTemperature': 60.5,
#      'dewPoint': 44.49,
#      'humidity': 0.56,
#      'pressure': 1017.4,
#      'windSpeed': 0.9,
#      'windGust': 4.29,
#      'windBearing': 192,
#      'cloudCover': 0.2,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 349.8},
#     {'time': 1618412400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 66.14,
#      'apparentTemperature': 66.14,
#      'dewPoint': 43.84,
#      'humidity': 0.44,
#      'pressure': 1017,
#      'windSpeed': 2.48,
#      'windGust': 4.73,
#      'windBearing': 178,
#      'cloudCover': 0.31,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 352.5},
#     {'time': 1618416000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 69.67,
#      'apparentTemperature': 69.67,
#      'dewPoint': 42.19,
#      'humidity': 0.37,
#      'pressure': 1016.2,
#      'windSpeed': 3.72,
#      'windGust': 6.39,
#      'windBearing': 278,
#      'cloudCover': 0.41,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 354},
#     {'time': 1618419600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.86,
#      'apparentTemperature': 68.86,
#      'dewPoint': 41.07,
#      'humidity': 0.36,
#      'pressure': 1015.7,
#      'windSpeed': 5.05,
#      'windGust': 9.47,
#      'windBearing': 249,
#      'cloudCover': 0.88,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 353.5},
#     {'time': 1618423200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 69.98,
#      'apparentTemperature': 69.98,
#      'dewPoint': 41.77,
#      'humidity': 0.36,
#      'pressure': 1015.2,
#      'windSpeed': 8.77,
#      'windGust': 13.07,
#      'windBearing': 245,
#      'cloudCover': 0.99,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 359.4},
#     {'time': 1618426800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.39,
#      'apparentTemperature': 68.39,
#      'dewPoint': 42.72,
#      'humidity': 0.39,
#      'pressure': 1014.5,
#      'windSpeed': 8.28,
#      'windGust': 13.56,
#      'windBearing': 244,
#      'cloudCover': 0.95,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 357.5},
#     {'time': 1618430400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 66.41,
#      'apparentTemperature': 66.41,
#      'dewPoint': 46.06,
#      'humidity': 0.48,
#      'pressure': 1013.9,
#      'windSpeed': 8.48,
#      'windGust': 14.68,
#      'windBearing': 243,
#      'cloudCover': 0.96,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 355.6},
#     {'time': 1618434000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0042,
#      'precipProbability': 0.04,
#      'precipType': 'rain',
#      'temperature': 64.67,
#      'apparentTemperature': 64.67,
#      'dewPoint': 48.53,
#      'humidity': 0.56,
#      'pressure': 1013.3,
#      'windSpeed': 6.45,
#      'windGust': 13.53,
#      'windBearing': 239,
#      'cloudCover': 0.91,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 354.3},
#     {'time': 1618437600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 63.47,
#      'apparentTemperature': 63.47,
#      'dewPoint': 50.8,
#      'humidity': 0.63,
#      'pressure': 1013,
#      'windSpeed': 7.56,
#      'windGust': 12.77,
#      'windBearing': 231,
#      'cloudCover': 0.9,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 354.8},
#     {'time': 1618441200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.95,
#      'apparentTemperature': 62.95,
#      'dewPoint': 51.39,
#      'humidity': 0.66,
#      'pressure': 1012.6,
#      'windSpeed': 6.74,
#      'windGust': 13.3,
#      'windBearing': 225,
#      'cloudCover': 0.81,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 355.8},
#     {'time': 1618444800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 61.61,
#      'apparentTemperature': 61.61,
#      'dewPoint': 51.49,
#      'humidity': 0.69,
#      'pressure': 1012.4,
#      'windSpeed': 5.94,
#      'windGust': 15.32,
#      'windBearing': 227,
#      'cloudCover': 0.79,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 358.3},
#     {'time': 1618448400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.55,
#      'apparentTemperature': 60.55,
#      'dewPoint': 52.09,
#      'humidity': 0.74,
#      'pressure': 1012.5,
#      'windSpeed': 5.22,
#      'windGust': 15.74,
#      'windBearing': 218,
#      'cloudCover': 0.85,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 359.5},
#     {'time': 1618452000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.87,
#      'apparentTemperature': 58.87,
#      'dewPoint': 52.87,
#      'humidity': 0.8,
#      'pressure': 1012.2,
#      'windSpeed': 5.58,
#      'windGust': 15.92,
#      'windBearing': 222,
#      'cloudCover': 0.75,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 359.6},
#     {'time': 1618455600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 57.93,
#      'apparentTemperature': 57.93,
#      'dewPoint': 53.08,
#      'humidity': 0.84,
#      'pressure': 1011.9,
#      'windSpeed': 5.36,
#      'windGust': 15.7,
#      'windBearing': 226,
#      'cloudCover': 0.69,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.2}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Rain starting in the morning.',
#    'icon': 'rain',
#    'data': [{'time': 1618459200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.74,
#      'apparentTemperature': 56.74,
#      'dewPoint': 53.24,
#      'humidity': 0.88,
#      'pressure': 1011.2,
#      'windSpeed': 4.85,
#      'windGust': 15.97,
#      'windBearing': 226,
#      'cloudCover': 0.81,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.4},
#     {'time': 1618462800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.69,
#      'apparentTemperature': 56.69,
#      'dewPoint': 53.03,
#      'humidity': 0.88,
#      'pressure': 1010.7,
#      'windSpeed': 3.07,
#      'windGust': 14.63,
#      'windBearing': 218,
#      'cloudCover': 0.84,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.6},
#     {'time': 1618466400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.42,
#      'apparentTemperature': 56.42,
#      'dewPoint': 52.9,
#      'humidity': 0.88,
#      'pressure': 1010.2,
#      'windSpeed': 3.14,
#      'windGust': 11.56,
#      'windBearing': 214,
#      'cloudCover': 0.93,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.7},
#     {'time': 1618470000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.96,
#      'apparentTemperature': 54.96,
#      'dewPoint': 52.35,
#      'humidity': 0.91,
#      'pressure': 1009.6,
#      'windSpeed': 1.53,
#      'windGust': 7.21,
#      'windBearing': 181,
#      'cloudCover': 0.89,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.1},
#     {'time': 1618473600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.42,
#      'apparentTemperature': 54.42,
#      'dewPoint': 53.39,
#      'humidity': 0.96,
#      'pressure': 1009.1,
#      'windSpeed': 2.69,
#      'windGust': 5.47,
#      'windBearing': 189,
#      'cloudCover': 0.96,
#      'uvIndex': 0,
#      'visibility': 9.833,
#      'ozone': 361.7},
#     {'time': 1618477200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.53,
#      'apparentTemperature': 54.53,
#      'dewPoint': 53.33,
#      'humidity': 0.96,
#      'pressure': 1008.8,
#      'windSpeed': 2.87,
#      'windGust': 4.56,
#      'windBearing': 181,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360},
#     {'time': 1618480800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.49,
#      'apparentTemperature': 53.49,
#      'dewPoint': 53.3,
#      'humidity': 0.99,
#      'pressure': 1008.5,
#      'windSpeed': 1.25,
#      'windGust': 4.74,
#      'windBearing': 120,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 359.5},
#     {'time': 1618484400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54,
#      'apparentTemperature': 54,
#      'dewPoint': 53.43,
#      'humidity': 0.98,
#      'pressure': 1008.2,
#      'windSpeed': 1.9,
#      'windGust': 4.78,
#      'windBearing': 114,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 9.046,
#      'ozone': 359.7},
#     {'time': 1618488000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.07,
#      'apparentTemperature': 55.07,
#      'dewPoint': 53.46,
#      'humidity': 0.94,
#      'pressure': 1008.3,
#      'windSpeed': 3.62,
#      'windGust': 5.08,
#      'windBearing': 125,
#      'cloudCover': 0.98,
#      'uvIndex': 1,
#      'visibility': 9.002,
#      'ozone': 360.7},
#     {'time': 1618491600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.66,
#      'apparentTemperature': 55.66,
#      'dewPoint': 53.35,
#      'humidity': 0.92,
#      'pressure': 1008,
#      'windSpeed': 3.86,
#      'windGust': 6.39,
#      'windBearing': 132,
#      'cloudCover': 0.98,
#      'uvIndex': 1,
#      'visibility': 9.026,
#      'ozone': 362.6},
#     {'time': 1618495200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.1,
#      'apparentTemperature': 56.1,
#      'dewPoint': 52.84,
#      'humidity': 0.89,
#      'pressure': 1007.8,
#      'windSpeed': 6.48,
#      'windGust': 8,
#      'windBearing': 131,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'visibility': 9.064,
#      'ozone': 363.8},
#     {'time': 1618498800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.27,
#      'apparentTemperature': 56.27,
#      'dewPoint': 53.35,
#      'humidity': 0.9,
#      'pressure': 1007.4,
#      'windSpeed': 7.22,
#      'windGust': 10.52,
#      'windBearing': 134,
#      'cloudCover': 0.99,
#      'uvIndex': 3,
#      'visibility': 9.264,
#      'ozone': 365.6},
#     {'time': 1618502400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0008,
#      'precipProbability': 0.02,
#      'precipType': 'rain',
#      'temperature': 56.17,
#      'apparentTemperature': 56.17,
#      'dewPoint': 53.17,
#      'humidity': 0.9,
#      'pressure': 1006.8,
#      'windSpeed': 7.93,
#      'windGust': 13.53,
#      'windBearing': 137,
#      'cloudCover': 0.99,
#      'uvIndex': 3,
#      'visibility': 9.665,
#      'ozone': 367},
#     {'time': 1618506000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0007,
#      'precipProbability': 0.06,
#      'precipType': 'rain',
#      'temperature': 54.96,
#      'apparentTemperature': 54.96,
#      'dewPoint': 52.99,
#      'humidity': 0.93,
#      'pressure': 1006,
#      'windSpeed': 8.75,
#      'windGust': 14.35,
#      'windBearing': 142,
#      'cloudCover': 0.98,
#      'uvIndex': 3,
#      'visibility': 8.458,
#      'ozone': 367.5},
#     {'time': 1618509600,
#      'summary': 'Possible Light Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.018,
#      'precipProbability': 0.52,
#      'precipType': 'rain',
#      'temperature': 54.28,
#      'apparentTemperature': 54.28,
#      'dewPoint': 52.99,
#      'humidity': 0.95,
#      'pressure': 1005.2,
#      'windSpeed': 6.85,
#      'windGust': 11.9,
#      'windBearing': 150,
#      'cloudCover': 1,
#      'uvIndex': 3,
#      'visibility': 6.863,
#      'ozone': 365.1},
#     {'time': 1618513200,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0593,
#      'precipProbability': 0.99,
#      'precipType': 'rain',
#      'temperature': 54.04,
#      'apparentTemperature': 54.04,
#      'dewPoint': 53.24,
#      'humidity': 0.97,
#      'pressure': 1004.6,
#      'windSpeed': 5.49,
#      'windGust': 9.98,
#      'windBearing': 152,
#      'cloudCover': 1,
#      'uvIndex': 3,
#      'visibility': 5.585,
#      'ozone': 366.4},
#     {'time': 1618516800,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0381,
#      'precipProbability': 0.92,
#      'precipType': 'rain',
#      'temperature': 53.88,
#      'apparentTemperature': 53.88,
#      'dewPoint': 53.1,
#      'humidity': 0.97,
#      'pressure': 1004.2,
#      'windSpeed': 3.99,
#      'windGust': 8.46,
#      'windBearing': 199,
#      'cloudCover': 1,
#      'uvIndex': 2,
#      'visibility': 8.902,
#      'ozone': 366.3},
#     {'time': 1618520400,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0575,
#      'precipProbability': 1,
#      'precipType': 'rain',
#      'temperature': 50.88,
#      'apparentTemperature': 50.88,
#      'dewPoint': 48.12,
#      'humidity': 0.9,
#      'pressure': 1004.6,
#      'windSpeed': 4.02,
#      'windGust': 19.36,
#      'windBearing': 302,
#      'cloudCover': 1,
#      'uvIndex': 1,
#      'visibility': 6.235,
#      'ozone': 367.3},
#     {'time': 1618524000,
#      'summary': 'Light Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0205,
#      'precipProbability': 0.65,
#      'precipType': 'rain',
#      'temperature': 51.23,
#      'apparentTemperature': 51.23,
#      'dewPoint': 46.15,
#      'humidity': 0.83,
#      'pressure': 1004.7,
#      'windSpeed': 5.52,
#      'windGust': 19.69,
#      'windBearing': 327,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 370.2},
#     {'time': 1618527600,
#      'summary': 'Light Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0189,
#      'precipProbability': 0.86,
#      'precipType': 'rain',
#      'temperature': 51.04,
#      'apparentTemperature': 51.04,
#      'dewPoint': 44.99,
#      'humidity': 0.8,
#      'pressure': 1004.9,
#      'windSpeed': 8.16,
#      'windGust': 21.24,
#      'windBearing': 9,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 371.4},
#     {'time': 1618531200,
#      'summary': 'Possible Drizzle',
#      'icon': 'rain',
#      'precipIntensity': 0.0071,
#      'precipProbability': 0.41,
#      'precipType': 'rain',
#      'temperature': 48.69,
#      'apparentTemperature': 45.81,
#      'dewPoint': 44.47,
#      'humidity': 0.85,
#      'pressure': 1005.6,
#      'windSpeed': 6.57,
#      'windGust': 20.07,
#      'windBearing': 351,
#      'cloudCover': 0.98,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 375.5},
#     {'time': 1618534800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0005,
#      'precipProbability': 0.07,
#      'precipType': 'rain',
#      'temperature': 47.95,
#      'apparentTemperature': 45.13,
#      'dewPoint': 42.05,
#      'humidity': 0.8,
#      'pressure': 1006.3,
#      'windSpeed': 6.19,
#      'windGust': 21.11,
#      'windBearing': 345,
#      'cloudCover': 0.77,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 376.5},
#     {'time': 1618538400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.35,
#      'apparentTemperature': 45.03,
#      'dewPoint': 41.37,
#      'humidity': 0.8,
#      'pressure': 1006.5,
#      'windSpeed': 5.12,
#      'windGust': 21.37,
#      'windBearing': 341,
#      'cloudCover': 0.75,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 380.3},
#     {'time': 1618542000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.76,
#      'apparentTemperature': 43.3,
#      'dewPoint': 40.54,
#      'humidity': 0.82,
#      'pressure': 1006.3,
#      'windSpeed': 4.92,
#      'windGust': 16.37,
#      'windBearing': 338,
#      'cloudCover': 0.55,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 383.5}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Possible drizzle in the morning and afternoon.',
#    'icon': 'rain',
#    'data': [{'time': 1618545600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.32,
#      'apparentTemperature': 43.8,
#      'dewPoint': 40.54,
#      'humidity': 0.83,
#      'pressure': 1006.1,
#      'windSpeed': 3.6,
#      'windGust': 17.03,
#      'windBearing': 332,
#      'cloudCover': 0.67,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 382.4},
#     {'time': 1618549200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.81,
#      'apparentTemperature': 42.29,
#      'dewPoint': 40.55,
#      'humidity': 0.85,
#      'pressure': 1006,
#      'windSpeed': 4.76,
#      'windGust': 14.94,
#      'windBearing': 337,
#      'cloudCover': 0.7,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 384.6},
#     {'time': 1618552800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0013,
#      'precipProbability': 0.05,
#      'precipType': 'rain',
#      'temperature': 43.53,
#      'apparentTemperature': 41.24,
#      'dewPoint': 40.42,
#      'humidity': 0.89,
#      'pressure': 1005.7,
#      'windSpeed': 4.18,
#      'windGust': 10.03,
#      'windBearing': 6,
#      'cloudCover': 0.7,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 391.8},
#     {'time': 1618556400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0003,
#      'precipProbability': 0.05,
#      'precipType': 'rain',
#      'temperature': 42.11,
#      'apparentTemperature': 42.11,
#      'dewPoint': 40.16,
#      'humidity': 0.93,
#      'pressure': 1005.7,
#      'windSpeed': 2.56,
#      'windGust': 10.12,
#      'windBearing': 347,
#      'cloudCover': 0.68,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 401.6},
#     {'time': 1618560000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.34,
#      'apparentTemperature': 40.34,
#      'dewPoint': 39.39,
#      'humidity': 0.96,
#      'pressure': 1005.5,
#      'windSpeed': 2.76,
#      'windGust': 11.9,
#      'windBearing': 322,
#      'cloudCover': 0.36,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 407.3},
#     {'time': 1618563600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 39.98,
#      'apparentTemperature': 39.98,
#      'dewPoint': 38.66,
#      'humidity': 0.95,
#      'pressure': 1005.3,
#      'windSpeed': 2.98,
#      'windGust': 13.94,
#      'windBearing': 297,
#      'cloudCover': 0.31,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 407},
#     {'time': 1618567200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 39.69,
#      'apparentTemperature': 39.69,
#      'dewPoint': 37.59,
#      'humidity': 0.92,
#      'pressure': 1005.1,
#      'windSpeed': 3,
#      'windGust': 15.17,
#      'windBearing': 294,
#      'cloudCover': 0.24,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 410.4},
#     {'time': 1618570800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 39.68,
#      'apparentTemperature': 37.69,
#      'dewPoint': 37.31,
#      'humidity': 0.91,
#      'pressure': 1005.1,
#      'windSpeed': 3.28,
#      'windGust': 13.37,
#      'windBearing': 292,
#      'cloudCover': 0.36,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 417.1},
#     {'time': 1618574400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.09,
#      'apparentTemperature': 38.79,
#      'dewPoint': 36.86,
#      'humidity': 0.79,
#      'pressure': 1005.2,
#      'windSpeed': 7.13,
#      'windGust': 17.37,
#      'windBearing': 303,
#      'cloudCover': 0.1,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 417.8},
#     {'time': 1618578000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.1,
#      'apparentTemperature': 40.68,
#      'dewPoint': 36.28,
#      'humidity': 0.71,
#      'pressure': 1004.7,
#      'windSpeed': 8.26,
#      'windGust': 16.84,
#      'windBearing': 296,
#      'cloudCover': 0.24,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 424.1},
#     {'time': 1618581600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.35,
#      'apparentTemperature': 41.48,
#      'dewPoint': 35.54,
#      'humidity': 0.66,
#      'pressure': 1004.5,
#      'windSpeed': 10.08,
#      'windGust': 17.17,
#      'windBearing': 303,
#      'cloudCover': 0.59,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 427.3},
#     {'time': 1618585200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0035,
#      'precipProbability': 0.1,
#      'precipType': 'rain',
#      'temperature': 48,
#      'apparentTemperature': 43.6,
#      'dewPoint': 36.04,
#      'humidity': 0.63,
#      'pressure': 1004,
#      'windSpeed': 9.91,
#      'windGust': 16.99,
#      'windBearing': 307,
#      'cloudCover': 0.68,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 427.9},
#     {'time': 1618588800,
#      'summary': 'Possible Drizzle',
#      'icon': 'rain',
#      'precipIntensity': 0.0039,
#      'precipProbability': 0.48,
#      'precipType': 'rain',
#      'temperature': 48.66,
#      'apparentTemperature': 44.39,
#      'dewPoint': 36.77,
#      'humidity': 0.63,
#      'pressure': 1003.7,
#      'windSpeed': 9.96,
#      'windGust': 17.24,
#      'windBearing': 287,
#      'cloudCover': 0.79,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 427.2},
#     {'time': 1618592400,
#      'summary': 'Possible Drizzle',
#      'icon': 'rain',
#      'precipIntensity': 0.0026,
#      'precipProbability': 0.29,
#      'precipType': 'rain',
#      'temperature': 49.75,
#      'apparentTemperature': 45.4,
#      'dewPoint': 36.78,
#      'humidity': 0.61,
#      'pressure': 1003.2,
#      'windSpeed': 11.01,
#      'windGust': 18,
#      'windBearing': 289,
#      'cloudCover': 0.87,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 430.5},
#     {'time': 1618596000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0005,
#      'precipProbability': 0.03,
#      'precipType': 'rain',
#      'temperature': 51.32,
#      'apparentTemperature': 51.32,
#      'dewPoint': 34.68,
#      'humidity': 0.53,
#      'pressure': 1002.8,
#      'windSpeed': 9.31,
#      'windGust': 16.95,
#      'windBearing': 314,
#      'cloudCover': 0.84,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 431.5},
#     {'time': 1618599600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.01,
#      'apparentTemperature': 52.01,
#      'dewPoint': 34.32,
#      'humidity': 0.51,
#      'pressure': 1002.8,
#      'windSpeed': 11.14,
#      'windGust': 22.44,
#      'windBearing': 312,
#      'cloudCover': 0.94,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 429.4},
#     {'time': 1618603200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0025,
#      'precipProbability': 0.2,
#      'precipType': 'rain',
#      'temperature': 50.49,
#      'apparentTemperature': 50.49,
#      'dewPoint': 38.11,
#      'humidity': 0.62,
#      'pressure': 1002.9,
#      'windSpeed': 11.93,
#      'windGust': 20.88,
#      'windBearing': 302,
#      'cloudCover': 0.99,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 426.6},
#     {'time': 1618606800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.63,
#      'apparentTemperature': 50.63,
#      'dewPoint': 38.12,
#      'humidity': 0.62,
#      'pressure': 1003.1,
#      'windSpeed': 11.27,
#      'windGust': 20.86,
#      'windBearing': 303,
#      'cloudCover': 0.99,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 422.6},
#     {'time': 1618610400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.001,
#      'precipProbability': 0.04,
#      'precipType': 'rain',
#      'temperature': 49.58,
#      'apparentTemperature': 45.4,
#      'dewPoint': 39.49,
#      'humidity': 0.68,
#      'pressure': 1003.7,
#      'windSpeed': 10.33,
#      'windGust': 20.2,
#      'windBearing': 309,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 423.9},
#     {'time': 1618614000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0011,
#      'precipProbability': 0.05,
#      'precipType': 'rain',
#      'temperature': 49.21,
#      'apparentTemperature': 45.41,
#      'dewPoint': 38.8,
#      'humidity': 0.67,
#      'pressure': 1004.3,
#      'windSpeed': 9.02,
#      'windGust': 20.51,
#      'windBearing': 316,
#      'cloudCover': 1,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 425.9},
#     {'time': 1618617600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0005,
#      'precipProbability': 0.04,
#      'precipType': 'rain',
#      'temperature': 47.65,
#      'apparentTemperature': 43.95,
#      'dewPoint': 39.92,
#      'humidity': 0.74,
#      'pressure': 1005.3,
#      'windSpeed': 7.89,
#      'windGust': 22.24,
#      'windBearing': 313,
#      'cloudCover': 0.98,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 423.7},
#     {'time': 1618621200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.08,
#      'apparentTemperature': 43.1,
#      'dewPoint': 39.98,
#      'humidity': 0.76,
#      'pressure': 1006.1,
#      'windSpeed': 8.27,
#      'windGust': 22.76,
#      'windBearing': 300,
#      'cloudCover': 0.99,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 421},
#     {'time': 1618624800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.03,
#      'apparentTemperature': 41.39,
#      'dewPoint': 38.8,
#      'humidity': 0.76,
#      'pressure': 1006.4,
#      'windSpeed': 9.3,
#      'windGust': 24.53,
#      'windBearing': 303,
#      'cloudCover': 0.95,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 424},
#     {'time': 1618628400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0008,
#      'precipProbability': 0.02,
#      'precipType': 'rain',
#      'temperature': 45.48,
#      'apparentTemperature': 40.64,
#      'dewPoint': 38.34,
#      'humidity': 0.76,
#      'pressure': 1006.5,
#      'windSpeed': 9.47,
#      'windGust': 24.78,
#      'windBearing': 307,
#      'cloudCover': 0.87,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 424.5}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Overcast throughout the day.',
#    'icon': 'cloudy',
#    'data': [{'time': 1618632000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.05,
#      'apparentTemperature': 41.19,
#      'dewPoint': 38.63,
#      'humidity': 0.78,
#      'pressure': 1006.8,
#      'windSpeed': 7.07,
#      'windGust': 23.37,
#      'windBearing': 309,
#      'cloudCover': 0.88,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 426.4},
#     {'time': 1618635600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.7,
#      'apparentTemperature': 40.89,
#      'dewPoint': 38.77,
#      'humidity': 0.8,
#      'pressure': 1006.8,
#      'windSpeed': 6.83,
#      'windGust': 21.47,
#      'windBearing': 319,
#      'cloudCover': 0.79,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 425.3},
#     {'time': 1618639200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.48,
#      'apparentTemperature': 40.65,
#      'dewPoint': 38.35,
#      'humidity': 0.79,
#      'pressure': 1006.5,
#      'windSpeed': 6.79,
#      'windGust': 18.37,
#      'windBearing': 317,
#      'cloudCover': 0.86,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 430.4},
#     {'time': 1618642800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.23,
#      'apparentTemperature': 40.57,
#      'dewPoint': 38.33,
#      'humidity': 0.8,
#      'pressure': 1006.6,
#      'windSpeed': 6.38,
#      'windGust': 18.54,
#      'windBearing': 316,
#      'cloudCover': 0.92,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 433.1},
#     {'time': 1618646400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.17,
#      'apparentTemperature': 40.3,
#      'dewPoint': 38.16,
#      'humidity': 0.79,
#      'pressure': 1006.9,
#      'windSpeed': 6.76,
#      'windGust': 18.32,
#      'windBearing': 324,
#      'cloudCover': 0.72,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 426.1},
#     {'time': 1618650000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0005,
#      'precipProbability': 0.05,
#      'precipType': 'rain',
#      'temperature': 43.25,
#      'apparentTemperature': 40.74,
#      'dewPoint': 38.21,
#      'humidity': 0.82,
#      'pressure': 1007.1,
#      'windSpeed': 4.4,
#      'windGust': 16.6,
#      'windBearing': 325,
#      'cloudCover': 0.66,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 420.4},
#     {'time': 1618653600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.87,
#      'apparentTemperature': 43.87,
#      'dewPoint': 38.4,
#      'humidity': 0.81,
#      'pressure': 1007.5,
#      'windSpeed': 2.45,
#      'windGust': 15.2,
#      'windBearing': 345,
#      'cloudCover': 0.88,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 420.3},
#     {'time': 1618657200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.03,
#      'apparentTemperature': 44.03,
#      'dewPoint': 39.41,
#      'humidity': 0.84,
#      'pressure': 1008.2,
#      'windSpeed': 2.44,
#      'windGust': 13.05,
#      'windBearing': 6,
#      'cloudCover': 0.93,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 418.6},
#     {'time': 1618660800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.86,
#      'apparentTemperature': 44.86,
#      'dewPoint': 39.63,
#      'humidity': 0.82,
#      'pressure': 1008.8,
#      'windSpeed': 2.21,
#      'windGust': 9.79,
#      'windBearing': 339,
#      'cloudCover': 0.91,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 421.9},
#     {'time': 1618664400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.65,
#      'apparentTemperature': 43.73,
#      'dewPoint': 39.69,
#      'humidity': 0.77,
#      'pressure': 1009,
#      'windSpeed': 5.91,
#      'windGust': 10.73,
#      'windBearing': 315,
#      'cloudCover': 0.92,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 421.7},
#     {'time': 1618668000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.96,
#      'apparentTemperature': 44.61,
#      'dewPoint': 38.11,
#      'humidity': 0.69,
#      'pressure': 1009.1,
#      'windSpeed': 7.26,
#      'windGust': 11.73,
#      'windBearing': 313,
#      'cloudCover': 0.92,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 422.4},
#     {'time': 1618671600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 49.54,
#      'apparentTemperature': 47,
#      'dewPoint': 36.86,
#      'humidity': 0.62,
#      'pressure': 1009,
#      'windSpeed': 6.23,
#      'windGust': 11.83,
#      'windBearing': 329,
#      'cloudCover': 0.83,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 423.5},
#     {'time': 1618675200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.11,
#      'apparentTemperature': 51.11,
#      'dewPoint': 35.96,
#      'humidity': 0.56,
#      'pressure': 1008.8,
#      'windSpeed': 7.21,
#      'windGust': 11.62,
#      'windBearing': 328,
#      'cloudCover': 0.91,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 422.9},
#     {'time': 1618678800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.52,
#      'apparentTemperature': 52.52,
#      'dewPoint': 35.96,
#      'humidity': 0.53,
#      'pressure': 1008.5,
#      'windSpeed': 5.94,
#      'windGust': 10.6,
#      'windBearing': 318,
#      'cloudCover': 0.78,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 421.5},
#     {'time': 1618682400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.57,
#      'apparentTemperature': 53.57,
#      'dewPoint': 35.82,
#      'humidity': 0.51,
#      'pressure': 1008.4,
#      'windSpeed': 6.78,
#      'windGust': 9.94,
#      'windBearing': 323,
#      'cloudCover': 0.96,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 425.6},
#     {'time': 1618686000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.07,
#      'apparentTemperature': 55.07,
#      'dewPoint': 35.8,
#      'humidity': 0.48,
#      'pressure': 1008.5,
#      'windSpeed': 6.89,
#      'windGust': 10.5,
#      'windBearing': 317,
#      'cloudCover': 0.93,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 426},
#     {'time': 1618689600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.87,
#      'apparentTemperature': 54.87,
#      'dewPoint': 35.52,
#      'humidity': 0.48,
#      'pressure': 1008.4,
#      'windSpeed': 6.68,
#      'windGust': 10.49,
#      'windBearing': 323,
#      'cloudCover': 0.92,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 422.5},
#     {'time': 1618693200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.21,
#      'apparentTemperature': 54.21,
#      'dewPoint': 35.93,
#      'humidity': 0.5,
#      'pressure': 1008.6,
#      'windSpeed': 6.3,
#      'windGust': 10.16,
#      'windBearing': 341,
#      'cloudCover': 0.96,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 413},
#     {'time': 1618696800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.64,
#      'apparentTemperature': 54.64,
#      'dewPoint': 35.31,
#      'humidity': 0.48,
#      'pressure': 1008.8,
#      'windSpeed': 6.82,
#      'windGust': 10.92,
#      'windBearing': 312,
#      'cloudCover': 0.86,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 400.4},
#     {'time': 1618700400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.48,
#      'apparentTemperature': 53.48,
#      'dewPoint': 35.47,
#      'humidity': 0.5,
#      'pressure': 1009,
#      'windSpeed': 5.51,
#      'windGust': 11.98,
#      'windBearing': 325,
#      'cloudCover': 0.95,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 395.3},
#     {'time': 1618704000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.99,
#      'apparentTemperature': 52.99,
#      'dewPoint': 35.26,
#      'humidity': 0.51,
#      'pressure': 1009.6,
#      'windSpeed': 5.53,
#      'windGust': 11.04,
#      'windBearing': 326,
#      'cloudCover': 0.92,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 394.3},
#     {'time': 1618707600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.99,
#      'apparentTemperature': 51.99,
#      'dewPoint': 36.44,
#      'humidity': 0.55,
#      'pressure': 1010.1,
#      'windSpeed': 4.8,
#      'windGust': 10.25,
#      'windBearing': 331,
#      'cloudCover': 0.87,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 395.7},
#     {'time': 1618711200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.5,
#      'apparentTemperature': 50.5,
#      'dewPoint': 36.58,
#      'humidity': 0.59,
#      'pressure': 1010.6,
#      'windSpeed': 2.44,
#      'windGust': 10.15,
#      'windBearing': 307,
#      'cloudCover': 0.88,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 395.4},
#     {'time': 1618714800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 49.69,
#      'apparentTemperature': 49.69,
#      'dewPoint': 37.28,
#      'humidity': 0.62,
#      'pressure': 1010.5,
#      'windSpeed': 2.17,
#      'windGust': 10.55,
#      'windBearing': 304,
#      'cloudCover': 0.77,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 395.2}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'data': [{'time': 1618718400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.24,
#      'apparentTemperature': 48.24,
#      'dewPoint': 37.81,
#      'humidity': 0.67,
#      'pressure': 1010.5,
#      'windSpeed': 2.36,
#      'windGust': 11.04,
#      'windBearing': 302,
#      'cloudCover': 0.81,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 394.2},
#     {'time': 1618722000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.61,
#      'apparentTemperature': 48.61,
#      'dewPoint': 37.78,
#      'humidity': 0.66,
#      'pressure': 1010.3,
#      'windSpeed': 2.17,
#      'windGust': 9.14,
#      'windBearing': 301,
#      'cloudCover': 0.76,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 395.8},
#     {'time': 1618725600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0014,
#      'precipProbability': 0.01,
#      'precipType': 'rain',
#      'temperature': 47.33,
#      'apparentTemperature': 45.71,
#      'dewPoint': 38.53,
#      'humidity': 0.71,
#      'pressure': 1009.8,
#      'windSpeed': 4.1,
#      'windGust': 8.8,
#      'windBearing': 308,
#      'cloudCover': 0.57,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 399.3},
#     {'time': 1618729200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.81,
#      'apparentTemperature': 47.81,
#      'dewPoint': 38.89,
#      'humidity': 0.71,
#      'pressure': 1009.8,
#      'windSpeed': 2.08,
#      'windGust': 8.73,
#      'windBearing': 303,
#      'cloudCover': 0.76,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 401.8},
#     {'time': 1618732800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.9,
#      'apparentTemperature': 46.9,
#      'dewPoint': 39.14,
#      'humidity': 0.74,
#      'pressure': 1010.3,
#      'windSpeed': 2.68,
#      'windGust': 10.94,
#      'windBearing': 303,
#      'cloudCover': 0.77,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 408.6},
#     {'time': 1618736400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.75,
#      'apparentTemperature': 46.75,
#      'dewPoint': 38.9,
#      'humidity': 0.74,
#      'pressure': 1010.2,
#      'windSpeed': 2.6,
#      'windGust': 11.08,
#      'windBearing': 307,
#      'cloudCover': 0.76,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 414.8},
#     {'time': 1618740000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.5,
#      'apparentTemperature': 44.59,
#      'dewPoint': 38.68,
#      'humidity': 0.74,
#      'pressure': 1010.4,
#      'windSpeed': 4.3,
#      'windGust': 11.12,
#      'windBearing': 309,
#      'cloudCover': 0.58,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 410.9},
#     {'time': 1618743600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.58,
#      'apparentTemperature': 44.88,
#      'dewPoint': 38.61,
#      'humidity': 0.74,
#      'pressure': 1010.8,
#      'windSpeed': 4.06,
#      'windGust': 13,
#      'windBearing': 306,
#      'cloudCover': 0.68,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 406.5},
#     {'time': 1618747200,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 49.69,
#      'apparentTemperature': 48.07,
#      'dewPoint': 39.5,
#      'humidity': 0.68,
#      'pressure': 1011.2,
#      'windSpeed': 4.65,
#      'windGust': 13.59,
#      'windBearing': 304,
#      'cloudCover': 0.5,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 403.1},
#     {'time': 1618750800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.41,
#      'apparentTemperature': 52.41,
#      'dewPoint': 40.8,
#      'humidity': 0.65,
#      'pressure': 1011.3,
#      'windSpeed': 7.02,
#      'windGust': 13.76,
#      'windBearing': 309,
#      'cloudCover': 0.19,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 404.5},
#     {'time': 1618754400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.79,
# ...
#      'humidity': 0.34,
#      'pressure': 1013.2,
#      'windSpeed': 10.75,
#      'windGust': 21.89,
#      'windBearing': 245,
#      'cloudCover': 0.08,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 361.5},
#     {'time': 1618938000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 71.99,
#      'apparentTemperature': 71.99,
#      'dewPoint': 39.8,
#      'humidity': 0.31,
#      'pressure': 1012.9,
#      'windSpeed': 10.71,
#      'windGust': 24.76,
#      'windBearing': 251,
#      'cloudCover': 0.12,
#      'uvIndex': 7,
#      'visibility': 10,
#      'ozone': 362},
#     {'time': 1618941600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.13,
#      'apparentTemperature': 74.13,
#      'dewPoint': 38.48,
#      'humidity': 0.28,
#      'pressure': 1012.4,
#      'windSpeed': 12.38,
#      'windGust': 22.85,
#      'windBearing': 235,
#      'cloudCover': 0.18,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 361.6},
#     {'time': 1618945200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.74,
#      'apparentTemperature': 74.74,
#      'dewPoint': 38.29,
#      'humidity': 0.27,
#      'pressure': 1011.8,
#      'windSpeed': 10.11,
#      'windGust': 24.92,
#      'windBearing': 243,
#      'cloudCover': 0.31,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 360.5},
#     {'time': 1618948800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.85,
#      'apparentTemperature': 74.85,
#      'dewPoint': 38.08,
#      'humidity': 0.26,
#      'pressure': 1011.4,
#      'windSpeed': 10.76,
#      'windGust': 22.45,
#      'windBearing': 245,
#      'cloudCover': 0.27,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 361.6},
#     {'time': 1618952400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 73.84,
#      'apparentTemperature': 73.84,
#      'dewPoint': 37.96,
#      'humidity': 0.27,
#      'pressure': 1011.1,
#      'windSpeed': 9.5,
#      'windGust': 22.84,
#      'windBearing': 226,
#      'cloudCover': 0.27,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 364.5},
#     {'time': 1618956000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.1,
#      'apparentTemperature': 74.1,
#      'dewPoint': 37.97,
#      'humidity': 0.27,
#      'pressure': 1011.1,
#      'windSpeed': 10.77,
#      'windGust': 21.06,
#      'windBearing': 221,
#      'cloudCover': 0.29,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 370.7},
#     {'time': 1618959600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 72.3,
#      'apparentTemperature': 72.3,
#      'dewPoint': 38.65,
#      'humidity': 0.29,
#      'pressure': 1010.8,
#      'windSpeed': 8.18,
#      'windGust': 19.92,
#      'windBearing': 222,
#      'cloudCover': 0.25,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 369.8},
#     {'time': 1618963200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 70.11,
#      'apparentTemperature': 70.11,
#      'dewPoint': 37.59,
#      'humidity': 0.3,
#      'pressure': 1010.8,
#      'windSpeed': 6.95,
#      'windGust': 17.87,
#      'windBearing': 206,
#      'cloudCover': 0.18,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 368.6},
#     {'time': 1618966800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.13,
#      'apparentTemperature': 68.13,
#      'dewPoint': 40.21,
#      'humidity': 0.36,
#      'pressure': 1011.6,
#      'windSpeed': 8.11,
#      'windGust': 22.39,
#      'windBearing': 203,
#      'cloudCover': 0.11,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 368.5},
#     {'time': 1618970400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 65.24,
#      'apparentTemperature': 65.24,
#      'dewPoint': 42.55,
#      'humidity': 0.44,
#      'pressure': 1012.1,
#      'windSpeed': 7.61,
#      'windGust': 25.32,
#      'windBearing': 204,
#      'cloudCover': 0.11,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.2},
#     {'time': 1618974000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.96,
#      'apparentTemperature': 62.96,
#      'dewPoint': 42.56,
#      'humidity': 0.47,
#      'pressure': 1012.1,
#      'windSpeed': 5.81,
#      'windGust': 22.84,
#      'windBearing': 212,
#      'cloudCover': 0.12,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 358}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Rain in the afternoon.',
#    'icon': 'rain',
#    'data': [{'time': 1618977600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.84,
#      'apparentTemperature': 60.84,
#      'dewPoint': 43.69,
#      'humidity': 0.53,
#      'pressure': 1011.9,
#      'windSpeed': 6.12,
#      'windGust': 21.4,
#      'windBearing': 193,
#      'cloudCover': 0.2,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360.9},
#     {'time': 1618981200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.8,
#      'apparentTemperature': 58.8,
#      'dewPoint': 43.64,
#      'humidity': 0.57,
#      'pressure': 1011.5,
#      'windSpeed': 4.8,
#      'windGust': 15.34,
#      'windBearing': 167,
#      'cloudCover': 0.22,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.1},
#     {'time': 1618984800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 57.83,
#      'apparentTemperature': 57.83,
#      'dewPoint': 43.28,
#      'humidity': 0.58,
#      'pressure': 1010.8,
#      'windSpeed': 2.57,
#      'windGust': 11.31,
#      'windBearing': 100,
#      'cloudCover': 0.19,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.8},
#     {'time': 1618988400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.26,
#      'apparentTemperature': 53.26,
#      'dewPoint': 43.09,
#      'humidity': 0.68,
#      'pressure': 1010.2,
#      'windSpeed': 2.48,
#      'windGust': 10.72,
#      'windBearing': 112,
#      'cloudCover': 0.15,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360.5},
#     {'time': 1618992000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.49,
#      'apparentTemperature': 51.49,
#      'dewPoint': 43.72,
#      'humidity': 0.75,
#      'pressure': 1009.7,
#      'windSpeed': 2.73,
#      'windGust': 10.42,
#      'windBearing': 108,
#      'cloudCover': 0.13,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 358.4},
#     {'time': 1618995600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.82,
#      'apparentTemperature': 50.82,
#      'dewPoint': 43.58,
#      'humidity': 0.76,
#      'pressure': 1008.9,
#      'windSpeed': 2.16,
#      'windGust': 11.13,
#      'windBearing': 142,
#      'cloudCover': 0.36,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 356.7},
#     {'time': 1618999200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.66,
#      'apparentTemperature': 50.66,
#      'dewPoint': 44.17,
#      'humidity': 0.78,
#      'pressure': 1008.1,
#      'windSpeed': 3.86,
#      'windGust': 13.29,
#      'windBearing': 130,
#      'cloudCover': 0.6,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 353.6},
#     {'time': 1619002800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.05,
#      'apparentTemperature': 52.05,
#      'dewPoint': 44.33,
#      'humidity': 0.75,
#      'pressure': 1007.4,
#      'windSpeed': 2.52,
#      'windGust': 13.61,
#      'windBearing': 150,
#      'cloudCover': 0.77,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 353.5},
#     {'time': 1619006400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.46,
#      'apparentTemperature': 55.46,
#      'dewPoint': 44.64,
#      'humidity': 0.67,
#      'pressure': 1006.7,
#      'windSpeed': 4.72,
#      'windGust': 17.62,
#      'windBearing': 157,
#      'cloudCover': 0.74,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 354.6},
#     {'time': 1619010000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 59.74,
#      'apparentTemperature': 59.74,
#      'dewPoint': 44.17,
#      'humidity': 0.56,
#      'pressure': 1005.7,
#      'windSpeed': 6.45,
#      'windGust': 19.26,
#      'windBearing': 189,
#      'cloudCover': 0.53,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 357.4},
#     {'time': 1619013600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.58,
#      'apparentTemperature': 62.58,
#      'dewPoint': 45.27,
#      'humidity': 0.53,
#      'pressure': 1004.8,
#      'windSpeed': 8.8,
#      'windGust': 18.57,
#      'windBearing': 200,
#      'cloudCover': 0.79,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 360},
#     {'time': 1619017200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 64.98,
#      'apparentTemperature': 64.98,
#      'dewPoint': 46.41,
#      'humidity': 0.51,
#      'pressure': 1003.7,
#      'windSpeed': 7.72,
#      'windGust': 20.51,
#      'windBearing': 201,
#      'cloudCover': 0.73,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 358.3},
#     {'time': 1619020800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0088,
#      'precipProbability': 0.12,
#      'precipType': 'rain',
#      'temperature': 66.55,
#      'apparentTemperature': 66.55,
#      'dewPoint': 47.54,
#      'humidity': 0.5,
#      'pressure': 1002.4,
#      'windSpeed': 8.58,
#      'windGust': 21.88,
#      'windBearing': 209,
#      'cloudCover': 0.83,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 360.8},
#     {'time': 1619024400,
#      'summary': 'Possible Light Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0224,
#      'precipProbability': 0.28,
#      'precipType': 'rain',
#      'temperature': 68.05,
#      'apparentTemperature': 68.05,
#      'dewPoint': 48.74,
#      'humidity': 0.5,
#      'pressure': 1001.4,
#      'windSpeed': 9.93,
#      'windGust': 22.28,
#      'windBearing': 237,
#      'cloudCover': 0.84,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 364.4},
#     {'time': 1619028000,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0422,
#      'precipProbability': 0.42,
#      'precipType': 'rain',
#      'temperature': 67.25,
#      'apparentTemperature': 67.25,
#      'dewPoint': 49.95,
#      'humidity': 0.54,
#      'pressure': 1000.4,
#      'windSpeed': 11.74,
#      'windGust': 23.6,
#      'windBearing': 220,
#      'cloudCover': 0.89,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 365.9},
#     {'time': 1619031600,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0403,
#      'precipProbability': 0.5,
#      'precipType': 'rain',
#      'temperature': 61.65,
#      'apparentTemperature': 61.65,
#      'dewPoint': 48.99,
#      'humidity': 0.63,
#      'pressure': 1001,
#      'windSpeed': 15.44,
#      'windGust': 28.22,
#      'windBearing': 231,
#      'cloudCover': 0.86,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 370.1},
#     {'time': 1619035200,
#      'summary': 'Possible Light Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0164,
#      'precipProbability': 0.31,
#      'precipType': 'rain',
#      'temperature': 55.88,
#      'apparentTemperature': 55.88,
#      'dewPoint': 43.16,
#      'humidity': 0.62,
#      'pressure': 1002,
#      'windSpeed': 16.65,
#      'windGust': 29.66,
#      'windBearing': 340,
#      'cloudCover': 0.69,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 374.3},
#     {'time': 1619038800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0093,
#      'precipProbability': 0.24,
#      'precipType': 'rain',
#      'temperature': 51.81,
#      'apparentTemperature': 51.81,
#      'dewPoint': 40.55,
#      'humidity': 0.65,
#      'pressure': 1002.9,
#      'windSpeed': 16.41,
#      'windGust': 28.09,
#      'windBearing': 304,
#      'cloudCover': 0.86,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 376.1},
#     {'time': 1619042400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0043,
#      'precipProbability': 0.05,
#      'precipType': 'rain',
#      'temperature': 50.14,
#      'apparentTemperature': 50.14,
#      'dewPoint': 38.08,
#      'humidity': 0.63,
#      'pressure': 1003.9,
#      'windSpeed': 16.24,
#      'windGust': 28.66,
#      'windBearing': 299,
#      'cloudCover': 0.86,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 378.3},
#     {'time': 1619046000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0025,
#      'precipProbability': 0.02,
#      'precipType': 'rain',
#      'temperature': 48.16,
#      'apparentTemperature': 42.11,
#      'dewPoint': 34.23,
#      'humidity': 0.58,
#      'pressure': 1005,
#      'windSpeed': 15.72,
#      'windGust': 29.08,
#      'windBearing': 311,
#      'cloudCover': 0.53,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 379.4},
#     {'time': 1619049600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0025,
#      'precipProbability': 0.02,
#      'precipType': 'rain',
#      'temperature': 45.7,
#      'apparentTemperature': 39.14,
#      'dewPoint': 31.01,
#      'humidity': 0.56,
#      'pressure': 1006.1,
#      'windSpeed': 15,
#      'windGust': 30.65,
#      'windBearing': 315,
#      'cloudCover': 0.45,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 384.3},
#     {'time': 1619053200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0.0008,
#      'precipProbability': 0.01,
#      'precipType': 'rain',
#      'temperature': 43.84,
#      'apparentTemperature': 36.85,
#      'dewPoint': 28.73,
#      'humidity': 0.55,
#      'pressure': 1007.2,
#      'windSpeed': 14.66,
#      'windGust': 32.29,
#      'windBearing': 314,
#      'cloudCover': 0.22,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 393.4},
#     {'time': 1619056800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0.0002,
#      'precipProbability': 0.01,
#      'precipType': 'rain',
#      'temperature': 42.45,
#      'apparentTemperature': 35.2,
#      'dewPoint': 27.57,
#      'humidity': 0.55,
#      'pressure': 1008,
#      'windSpeed': 14.26,
#      'windGust': 33,
#      'windBearing': 313,
#      'cloudCover': 0.11,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 400.3},
#     {'time': 1619060400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 41.3,
#      'apparentTemperature': 34.07,
#      'dewPoint': 27.74,
#      'humidity': 0.58,
#      'pressure': 1008.4,
#      'windSpeed': 13.17,
#      'windGust': 31.47,
#      'windBearing': 310,
#      'cloudCover': 0.1,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 403.2}]},
#   'offset': -4}]

# %%
# FORMAT THE TEMPERATURE DATA TO VISUALIZE ON THE MAP
at_ts = {}
dt['hourly']['data']
# Out:
# [{'time': 1618977600,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 60.84,
#   'apparentTemperature': 60.84,
#   'dewPoint': 43.69,
#   'humidity': 0.53,
#   'pressure': 1011.9,
#   'windSpeed': 6.12,
#   'windGust': 21.4,
#   'windBearing': 193,
#   'cloudCover': 0.2,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 360.9},
#  {'time': 1618981200,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 58.8,
#   'apparentTemperature': 58.8,
#   'dewPoint': 43.64,
#   'humidity': 0.57,
#   'pressure': 1011.5,
#   'windSpeed': 4.8,
#   'windGust': 15.34,
#   'windBearing': 167,
#   'cloudCover': 0.22,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 362.1},
#  {'time': 1618984800,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 57.83,
#   'apparentTemperature': 57.83,
#   'dewPoint': 43.28,
#   'humidity': 0.58,
#   'pressure': 1010.8,
#   'windSpeed': 2.57,
#   'windGust': 11.31,
#   'windBearing': 100,
#   'cloudCover': 0.19,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 363.8},
#  {'time': 1618988400,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 53.26,
#   'apparentTemperature': 53.26,
#   'dewPoint': 43.09,
#   'humidity': 0.68,
#   'pressure': 1010.2,
#   'windSpeed': 2.48,
#   'windGust': 10.72,
#   'windBearing': 112,
#   'cloudCover': 0.15,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 360.5},
#  {'time': 1618992000,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 51.49,
#   'apparentTemperature': 51.49,
#   'dewPoint': 43.72,
#   'humidity': 0.75,
#   'pressure': 1009.7,
#   'windSpeed': 2.73,
#   'windGust': 10.42,
#   'windBearing': 108,
#   'cloudCover': 0.13,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 358.4},
#  {'time': 1618995600,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 50.82,
#   'apparentTemperature': 50.82,
#   'dewPoint': 43.58,
#   'humidity': 0.76,
#   'pressure': 1008.9,
#   'windSpeed': 2.16,
#   'windGust': 11.13,
#   'windBearing': 142,
#   'cloudCover': 0.36,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 356.7},
#  {'time': 1618999200,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 50.66,
#   'apparentTemperature': 50.66,
#   'dewPoint': 44.17,
#   'humidity': 0.78,
#   'pressure': 1008.1,
#   'windSpeed': 3.86,
#   'windGust': 13.29,
#   'windBearing': 130,
#   'cloudCover': 0.6,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 353.6},
#  {'time': 1619002800,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 52.05,
#   'apparentTemperature': 52.05,
#   'dewPoint': 44.33,
#   'humidity': 0.75,
#   'pressure': 1007.4,
#   'windSpeed': 2.52,
#   'windGust': 13.61,
#   'windBearing': 150,
#   'cloudCover': 0.77,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 353.5},
#  {'time': 1619006400,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.46,
#   'apparentTemperature': 55.46,
#   'dewPoint': 44.64,
#   'humidity': 0.67,
#   'pressure': 1006.7,
#   'windSpeed': 4.72,
#   'windGust': 17.62,
#   'windBearing': 157,
#   'cloudCover': 0.74,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 354.6},
#  {'time': 1619010000,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 59.74,
#   'apparentTemperature': 59.74,
#   'dewPoint': 44.17,
#   'humidity': 0.56,
#   'pressure': 1005.7,
#   'windSpeed': 6.45,
#   'windGust': 19.26,
#   'windBearing': 189,
#   'cloudCover': 0.53,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 357.4},
#  {'time': 1619013600,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 62.58,
#   'apparentTemperature': 62.58,
#   'dewPoint': 45.27,
#   'humidity': 0.53,
#   'pressure': 1004.8,
#   'windSpeed': 8.8,
#   'windGust': 18.57,
#   'windBearing': 200,
#   'cloudCover': 0.79,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 360},
#  {'time': 1619017200,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 64.98,
#   'apparentTemperature': 64.98,
#   'dewPoint': 46.41,
#   'humidity': 0.51,
#   'pressure': 1003.7,
#   'windSpeed': 7.72,
#   'windGust': 20.51,
#   'windBearing': 201,
#   'cloudCover': 0.73,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 358.3},
#  {'time': 1619020800,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0088,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 66.55,
#   'apparentTemperature': 66.55,
#   'dewPoint': 47.54,
#   'humidity': 0.5,
#   'pressure': 1002.4,
#   'windSpeed': 8.58,
#   'windGust': 21.88,
#   'windBearing': 209,
#   'cloudCover': 0.83,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 360.8},
#  {'time': 1619024400,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0224,
#   'precipProbability': 0.28,
#   'precipType': 'rain',
#   'temperature': 68.05,
#   'apparentTemperature': 68.05,
#   'dewPoint': 48.74,
#   'humidity': 0.5,
#   'pressure': 1001.4,
#   'windSpeed': 9.93,
#   'windGust': 22.28,
#   'windBearing': 237,
#   'cloudCover': 0.84,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 364.4},
#  {'time': 1619028000,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0422,
#   'precipProbability': 0.42,
#   'precipType': 'rain',
#   'temperature': 67.25,
#   'apparentTemperature': 67.25,
#   'dewPoint': 49.95,
#   'humidity': 0.54,
#   'pressure': 1000.4,
#   'windSpeed': 11.74,
#   'windGust': 23.6,
#   'windBearing': 220,
#   'cloudCover': 0.89,
#   'uvIndex': 4,
#   'visibility': 10,
#   'ozone': 365.9},
#  {'time': 1619031600,
#   'summary': 'Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0403,
#   'precipProbability': 0.5,
#   'precipType': 'rain',
#   'temperature': 61.65,
#   'apparentTemperature': 61.65,
#   'dewPoint': 48.99,
#   'humidity': 0.63,
#   'pressure': 1001,
#   'windSpeed': 15.44,
#   'windGust': 28.22,
#   'windBearing': 231,
#   'cloudCover': 0.86,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 370.1},
#  {'time': 1619035200,
#   'summary': 'Possible Light Rain',
#   'icon': 'rain',
#   'precipIntensity': 0.0164,
#   'precipProbability': 0.31,
#   'precipType': 'rain',
#   'temperature': 55.88,
#   'apparentTemperature': 55.88,
#   'dewPoint': 43.16,
#   'humidity': 0.62,
#   'pressure': 1002,
#   'windSpeed': 16.65,
#   'windGust': 29.66,
#   'windBearing': 340,
#   'cloudCover': 0.69,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 374.3},
#  {'time': 1619038800,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0093,
#   'precipProbability': 0.24,
#   'precipType': 'rain',
#   'temperature': 51.81,
#   'apparentTemperature': 51.81,
#   'dewPoint': 40.55,
#   'humidity': 0.65,
#   'pressure': 1002.9,
#   'windSpeed': 16.41,
#   'windGust': 28.09,
#   'windBearing': 304,
#   'cloudCover': 0.86,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 376.1},
#  {'time': 1619042400,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0043,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 50.14,
#   'apparentTemperature': 50.14,
#   'dewPoint': 38.08,
#   'humidity': 0.63,
#   'pressure': 1003.9,
#   'windSpeed': 16.24,
#   'windGust': 28.66,
#   'windBearing': 299,
#   'cloudCover': 0.86,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 378.3},
#  {'time': 1619046000,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 48.16,
#   'apparentTemperature': 42.11,
#   'dewPoint': 34.23,
#   'humidity': 0.58,
#   'pressure': 1005,
#   'windSpeed': 15.72,
#   'windGust': 29.08,
#   'windBearing': 311,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 379.4},
#  {'time': 1619049600,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0025,
#   'precipProbability': 0.02,
#   'precipType': 'rain',
#   'temperature': 45.7,
#   'apparentTemperature': 39.14,
#   'dewPoint': 31.01,
#   'humidity': 0.56,
#   'pressure': 1006.1,
#   'windSpeed': 15,
#   'windGust': 30.65,
#   'windBearing': 315,
#   'cloudCover': 0.45,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 384.3},
#  {'time': 1619053200,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0008,
#   'precipProbability': 0.01,
#   'precipType': 'rain',
#   'temperature': 43.84,
#   'apparentTemperature': 36.85,
#   'dewPoint': 28.73,
#   'humidity': 0.55,
#   'pressure': 1007.2,
#   'windSpeed': 14.66,
#   'windGust': 32.29,
#   'windBearing': 314,
#   'cloudCover': 0.22,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 393.4},
#  {'time': 1619056800,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0.0002,
#   'precipProbability': 0.01,
#   'precipType': 'rain',
#   'temperature': 42.45,
#   'apparentTemperature': 35.2,
#   'dewPoint': 27.57,
#   'humidity': 0.55,
#   'pressure': 1008,
#   'windSpeed': 14.26,
#   'windGust': 33,
#   'windBearing': 313,
#   'cloudCover': 0.11,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 400.3},
#  {'time': 1619060400,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 41.3,
#   'apparentTemperature': 34.07,
#   'dewPoint': 27.74,
#   'humidity': 0.58,
#   'pressure': 1008.4,
#   'windSpeed': 13.17,
#   'windGust': 31.47,
#   'windBearing': 310,
#   'cloudCover': 0.1,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 403.2}]

# %%
at_ts = {}
for i in range(0, len(weather_arr)):
    for j in range(0,len(weather_arr[i]['hourly']['data'])):
        time_add = weather_arr[i]['hourly']['data'][j]['time']
        time_add = time.strftime('%Y-%m-%dT%H:%M:%S.000-04:00', time.localtime(time_add))
        temp_c = (weather_arr[i]['hourly']['data'][j]['temperature'] - 32) * (5/9)
        at_ts[time_add] = temp_c
at_ts
# Out:
# {'2021-04-14T00:00:00.000-04:00': 10.98888888888889,
#  '2021-04-14T01:00:00.000-04:00': 10.366666666666665,
#  '2021-04-14T02:00:00.000-04:00': 8.861111111111112,
#  '2021-04-14T03:00:00.000-04:00': 7.988888888888891,
#  '2021-04-14T04:00:00.000-04:00': 7.2111111111111095,
#  '2021-04-14T05:00:00.000-04:00': 6.983333333333333,
#  '2021-04-14T06:00:00.000-04:00': 6.749999999999999,
#  '2021-04-14T07:00:00.000-04:00': 6.744444444444445,
#  '2021-04-14T08:00:00.000-04:00': 9.272222222222222,
#  '2021-04-14T09:00:00.000-04:00': 12.383333333333333,
#  '2021-04-14T10:00:00.000-04:00': 15.833333333333334,
#  '2021-04-14T11:00:00.000-04:00': 18.96666666666667,
#  '2021-04-14T12:00:00.000-04:00': 20.92777777777778,
#  '2021-04-14T13:00:00.000-04:00': 20.477777777777778,
#  '2021-04-14T14:00:00.000-04:00': 21.1,
#  '2021-04-14T15:00:00.000-04:00': 20.21666666666667,
#  '2021-04-20T17:00:00.000-04:00': 23.244444444444447,
#  '2021-04-20T18:00:00.000-04:00': 23.388888888888886,
#  '2021-04-20T19:00:00.000-04:00': 22.38888888888889,
#  '2021-04-20T20:00:00.000-04:00': 21.172222222222224,
#  '2021-04-20T21:00:00.000-04:00': 20.07222222222222,
#  '2021-04-20T22:00:00.000-04:00': 18.466666666666665,
#  '2021-04-20T23:00:00.000-04:00': 17.200000000000003,
#  '2021-04-21T00:00:00.000-04:00': 16.022222222222226,
#  '2021-04-21T01:00:00.000-04:00': 14.888888888888888,
#  '2021-04-21T02:00:00.000-04:00': 14.35,
#  '2021-04-21T03:00:00.000-04:00': 11.81111111111111,
#  '2021-04-21T04:00:00.000-04:00': 10.82777777777778,
#  '2021-04-21T05:00:00.000-04:00': 10.455555555555556,
#  '2021-04-21T06:00:00.000-04:00': 10.366666666666665,
#  '2021-04-21T07:00:00.000-04:00': 11.138888888888888,
#  '2021-04-21T08:00:00.000-04:00': 13.033333333333335,
#  '2021-04-21T09:00:00.000-04:00': 15.411111111111113,
#  '2021-04-21T10:00:00.000-04:00': 16.988888888888887,
#  '2021-04-21T11:00:00.000-04:00': 18.322222222222226,
#  '2021-04-21T12:00:00.000-04:00': 19.194444444444443,
#  '2021-04-21T13:00:00.000-04:00': 20.02777777777778,
#  '2021-04-21T14:00:00.000-04:00': 19.583333333333336,
#  '2021-04-21T15:00:00.000-04:00': 16.47222222222222,
#  '2021-04-21T16:00:00.000-04:00': 13.26666666666667,
#  '2021-04-21T17:00:00.000-04:00': 11.005555555555556,
#  '2021-04-21T18:00:00.000-04:00': 10.07777777777778,
#  '2021-04-21T19:00:00.000-04:00': 8.977777777777776,
#  '2021-04-21T20:00:00.000-04:00': 7.611111111111113,
#  '2021-04-21T21:00:00.000-04:00': 6.57777777777778,
#  '2021-04-21T22:00:00.000-04:00': 5.805555555555557,
#  '2021-04-21T23:00:00.000-04:00': 5.166666666666665}

# %%
# GET FORECAST OF METEOROLOGICAL DATA

# For next 168 hours
# urlt = "https://api.darksky.net/forecast/{}/{},{}?extend=hourly?exclude=currently,minutely,daily,alerts,flags".format(ds_key, locationt[0], locationt[1])

# For next 48 hours
url_fc = "https://api.darksky.net/forecast/{}/{},{}?exclude=currently,minutely,daily,alerts,flags".format(ds_key, locationt[0], locationt[1])

response_fc = requests.request("GET", url_fc)

dt_fc = eval(response_fc.text)

# %%
# FORMAT THE FORCAST INTO THE HISTORICAL ARRAY
at_ts_fc = {}
for i in range(0, len(dt_fc['hourly']['data'])):
    for j in range(0,len(dt_fc['hourly']['data'])):
        time_add = dt_fc['hourly']['data'][j]['time']
        time_add = time.strftime('%Y-%m-%dT%H:%M:%S.000-04:00', time.localtime(time_add))
        temp_c = (dt_fc['hourly']['data'][j]['temperature'] - 32) * (5/9)
        at_ts_fc[time_add] = temp_c

# GET RID OF ANY OVERLAPPING DATA
hours_since_mn = int(seconds_since_midnight / 60 / 60)
hours_to_mn = 23 - hours_since_mn

for i in range(0,hours_to_mn):
#  '2021-04-21T23:00:00.000-04:00': 5.166666666666665,
#  '2021-04-22T00:00:00.000-04:00': 4.655555555555557,
#  '2021-04-22T01:00:00.000-04:00': 4.500000000000001,
#  '2021-04-22T02:00:00.000-04:00': 4.188888888888888,
#  '2021-04-22T03:00:00.000-04:00': 3.800000000000002,
#  '2021-04-22T04:00:00.000-04:00': 3.4388888888888878,
#  '2021-04-22T05:00:00.000-04:00': 3.1500000000000012,
#  '2021-04-22T06:00:00.000-04:00': 2.8388888888888886,
#  '2021-04-22T07:00:00.000-04:00': 2.688888888888891,
#  '2021-04-22T08:00:00.000-04:00': 3.099999999999999,
#  '2021-04-22T09:00:00.000-04:00': 3.9944444444444436,
#  '2021-04-22T10:00:00.000-04:00': 4.938888888888889,
#  '2021-04-22T11:00:00.000-04:00': 5.772222222222223,
#  '2021-04-22T12:00:00.000-04:00': 6.522222222222224,
#  '2021-04-22T13:00:00.000-04:00': 7.583333333333333,
#  '2021-04-22T14:00:00.000-04:00': 8.58888888888889,
#  '2021-04-22T15:00:00.000-04:00': 9.816666666666668,
#  '2021-04-22T16:00:00.000-04:00': 10.261111111111111,
#  '2021-04-22T17:00:00.000-04:00': 11.005555555555556,
#  '2021-04-22T18:00:00.000-04:00': 10.894444444444444,
#  '2021-04-22T19:00:00.000-04:00': 10.183333333333334,
#  '2021-04-22T20:00:00.000-04:00': 8.822222222222225,
#  '2021-04-22T21:00:00.000-04:00': 8.066666666666668,
#  '2021-04-22T22:00:00.000-04:00': 7.300000000000001,
#  '2021-04-22T23:00:00.000-04:00': 6.822222222222223,
#  '2021-04-23T00:00:00.000-04:00': 6.383333333333335,
#  '2021-04-23T01:00:00.000-04:00': 6.050000000000001,
#  '2021-04-23T02:00:00.000-04:00': 5.650000000000001,
#  '2021-04-23T03:00:00.000-04:00': 5.3055555555555545,
#  '2021-04-23T04:00:00.000-04:00': 5.011111111111113,
#  '2021-04-23T05:00:00.000-04:00': 4.916666666666668,
#  '2021-04-23T06:00:00.000-04:00': 4.8388888888888895,
#  '2021-04-23T07:00:00.000-04:00': 5.133333333333335,
#  '2021-04-23T08:00:00.000-04:00': 6.433333333333333,
#  '2021-04-23T09:00:00.000-04:00': 8.150000000000002,
#  '2021-04-23T10:00:00.000-04:00': 9.972222222222225,
#  '2021-04-23T11:00:00.000-04:00': 11.544444444444446}

# %%
# DISPLAY RESULTS

plt.figure(figsize = (18,9))
plt.plot(at_ts.keys(), at_ts.values(), linewidth=1, color='darkred', label="Air Temperature")
plt.plot(wt_ts.keys(), wt_ts.values(), linewidth=1, color='navy', label="Stream Temperature")
# PUT FORECASTED TEMPERATURE HERE
plt.grid(color='grey')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(0,len(at_ts),12),rotation=90, fontsize=16)
plt.title('USGS Stream Gauge {} ({}, {})'.format(gage, round(y,7), round(x,7)), fontsize=18)
plt.xlabel('',fontsize=16)
plt.ylabel('Temperature, C',fontsize=16)
#plt.savefig('timeseries_temperature.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## FROM HERE SEND TO WT MODEL AND GET FORECAST
