# %% [markdown]
# ### Probabilistic Stream Temperature Forecasting Application Programming Interface (API)
# ##### 48-Hour temperature predictions for USGS gage 01389005
#
# Temperature of freshwater systems is a well--studied phenomenon with a number of physical, biological, and ecological responses. Advancement in accurate forecasting of real--time stream temperatures is critical to regional water management because it informs policy decisions. For example, the Delaware River Basin Commission (DRBC) regulates freshwater withdraws from reservoirs to maintain a maximum river temperature during summer months to support aquatic wildlife habitat. The ability to estimate temperature is impacted by the complexity of interactions between stream and river networks, ground water, and meteorological conditions. A number of attempts have been made to mechanistically predict temperature with some success, but these methods require persistent measurements and an understanding of the direct relationship between weather and its impacts on stream conditions.  This work presents a machine learning (ML) model based on the spatial configuration of streams and their historical temperature relationships given external factors. Specifically, our approach relies on a novel ML architecture that combines the signal processing power of wavelet analysis, TensorFlow Probability layers, and graph convolution network layers. Via spectral clustering, we extract structural properties of the geographical area being analyzed, and extract correlative relationships between relevant time--varying signals and the area geography. The result is a temperature forecast with hourly resolution tailored to the particular geography in question.  We show that our approach outperforms other state--of--the--art temperature modeling approaches in an area surrounding the Mid-Atlantic hydrologic region. Finally, we discuss the potential to scale this approach to other watersheds.
#
# Paper Submitted:
#
# McDonald, A.W.E., Campagna M., Haag S., Perez L.B. & Shokoufandeh, A. (2021). Graph Convolutions with Wavelets for Probabilistic Stream Temperature Forecasting. AGU Water Resources Research.

# %%
from ipyleaflet import Map, basemaps, Polygon, DrawControl, WidgetControl, GeoJSON, MeasureControl, WKTLayer, Popup
from ipywidgets import IntSlider, ColorPicker, jslink, HTML
import sys
import requests
import geojson
import json
import shapely
from shapely.geometry import shape, GeometryCollection
import matplotlib.pyplot as plt
import xmltodict
import pprint
import time
from datetime import datetime

# %%
# LOAD IN THE GAGE DATA
with open('usgs_gages.geojson') as json_file:
    features = json.load(json_file)["features"]
with open('usgs_gages.geojson') as json_file:
    gage_lkup = json.load(json_file)

gages = GeometryCollection([shape(feature["geometry"]) for feature in features])

with open('usgs_gages_wtshds.geojson') as json_file:
    features = json.load(json_file)["features"]

gage_watersheds = GeometryCollection([shape(feature["geometry"]).buffer(0) for feature in features])

# %%
# PICK THE USGS GAGE OR LOCATION THAT YOU WANT MODELED

gage_labels = {'01382170': [gages[0].coords.xy[0][0], gages[0].coords.xy[1][0]],
         '01382210': [gages[1].coords.xy[0][0], gages[1].coords.xy[1][0]],
         '01382310': [gages[2].coords.xy[0][0], gages[2].coords.xy[1][0]],
         '01382381': [gages[3].coords.xy[0][0], gages[3].coords.xy[1][0]], 
         '01382385': [gages[4].coords.xy[0][0], gages[4].coords.xy[1][0]], 
         '01389005': [gages[5].coords.xy[0][0], gages[5].coords.xy[1][0]]}

# Map centred on target watersheds
map_center = (gage_watersheds[5].centroid.coords[0][1], gage_watersheds[5].centroid.coords[0][0])
displaymap1 = Map(center = map_center, zoom = 9, min_zoom = 1, max_zoom = 20,  scroll_wheel_zoom = True,
    basemap=basemaps.Esri.WorldStreetMap)

# Enable drawing points/polygons/lines
draw_control = DrawControl()
draw_control.point =  {
    "shapeOptions": {
        "color": "#6bc2e5",
        "weight": 1,
        "opacity": 1.0
    }
}
draw_control.polyline =  {
    "shapeOptions": {
        "color": "#6bc2e5",
        "weight": 4,
        "opacity": 1.0
    }
}
draw_control.polygon = {
    "shapeOptions": {
        "fillColor": "#6be5c3",
        "color": "#6be5c3",
        "fillOpacity": 0.3
    },
    "drawError": {
        "color": "#dd253b",
        "message": "Oups!"
    },
    "allowIntersection": True
}

watersheds_layer = WKTLayer(
    wkt_string=gage_watersheds.wkt,
    style={
        'opacity': 1, 'dashArray': '2', 'fillOpacity': 0.2, 'weight': 1, 'color': 'blue'
    }
)

gages_layer = WKTLayer(
    wkt_string=gages.wkt,
    label = gage_labels
    
)

# Save the drawn geometry to a geojson
draw_feature_collection = {
    'type': 'FeatureCollection',
    'features': []
}

click_feature_collection = {
    'type': 'FeatureCollection',
    'features': []
}

def handle_draw(self, action, geo_json):
    # Save the GeoJSON when it's drawn on the map  
    draw_feature_collection['features'].append(geo_json)

def handle_click(**kwargs):
    # Save the last clicked point
    click_feature_collection['features'].append(kwargs['feature'])
    x = kwargs['feature']['geometry']['coordinates'][0]
    y = kwargs['feature']['geometry']['coordinates'][1]
    for label, coords in gage_labels.items():
        if gage_labels[label][0] == x and gage_labels[label][1] == y:
            gage = label
            print('Selected USGS Gage Station {} at ({},{})'.format(gage, y, x), end='\r')

gages_layer.on_click(handle_click)

# Add everything into the map
draw_control.on_draw(handle_draw)
displaymap1.add_control(draw_control)
displaymap1.add_layer(gages_layer)
displaymap1.add_layer(watersheds_layer)

displaymap1
# Out:
# Map(center=[40.98064101320725, -74.36654960990295], controls=(ZoomControl(options=['position', 'zoom_in_text',…
# Selected USGS Gage Station 01389005 at (40.89638889000001,-74.2691667)

# %%
# Show the clicked gage
last_geom_idx = len(click_feature_collection['features']) - 1
last_geom = click_feature_collection['features'][last_geom_idx]['geometry']
x = last_geom['coordinates'][0]
y = last_geom['coordinates'][1]
for label, coords in gage_labels.items():
        if gage_labels[label][0] == x and gage_labels[label][1] == y:
            gage = label
print(gage)
last_geom
# Out:
# 01389005
# {'type': 'Point', 'coordinates': [-74.2691667, 40.89638889000001]}

# %%
# GET NWIS DATA for POR of Last 7 Days
nwis_url = 'http://waterservices.usgs.gov/nwis/iv/?sites={}&parameterCd=00010&period=P7D'.format(gage)
#_headers = {'Content-Type': 'application/json'}
_r = requests.post(nwis_url, allow_redirects=True, verify=True)
_r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><ns1:timeSeriesResponse xsi:schemaLocation="http://www.cuahsi.org/waterML/1.1/ http://waterservices.usgs.gov/WaterML-1.1.xsd" xmlns:ns1="http://www.cuahsi.org/waterML/1.1/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><ns1:queryInfo xmlns:ns2="http://www.cuahsi.org/waterML/1.1/"><ns2:queryURL>http://waterservices.usgs.gov/nwis/iv/sites=01389005&amp;parameterCd=00010&amp;period=P7D</ns2:queryURL><ns2:criteria><ns2:locationParam>[ALL:01389005]</ns2:locationParam><ns2:variableParam>[00010]</ns2:variableParam></ns2:criteria><ns2:note title="filter:sites">[ALL:01389005]</ns2:note><ns2:note title="filter:timeRange">[mode=PERIOD, period=P7D, modifiedSince=null]</ns2:note><ns2:note title="filter:methodId">methodIds=[ALL]</ns2:note><ns2:note title="requestDT">2021-04-27T20:37:27.839Z</ns2:note><ns2:note title="requestId">618c3be0-a798-11eb-8a3c-2cea7f5e5ede</ns2:note><ns2:note title="disclaimer">Provisional data are subject to revision. Go to http://waterdata.usgs.gov/nwis/help/?provisional for more information.</ns2:note><ns2:note title="server">sdas01</ns2:note></ns1:queryInfo><ns1:timeSeries name="USGS:01389005:00010:00000" xmlns:ns1="http://www.cuahsi.org/waterML/1.1/"><ns1:sourceInfo xsi:type="ns1:SiteInfoType" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><ns1:siteName>Passaic River below Pompton Riv at Two Bridges NJ</ns1:siteName><ns1:siteCode network="NWIS" agencyCode="USGS">01389005</ns1:siteCode><ns1:timeZoneInfo siteUsesDaylightSavingsTime="true"><ns1:defaultTimeZone zoneOffset="-05:00" zoneAbbreviation="EST"/><ns1:daylightSavingsTimeZone zoneOffset="-04:00" zoneAbbreviation="EDT"/></ns1:timeZoneInfo><ns1:geoLocation><ns1:geogLocation xsi:type="ns1:LatLonPointType" srs="EPSG:4326"><ns1:latitude>40.89638889</ns1:latitude><ns1:longitude>-74.2691667</ns1:longitude></ns1:geogLocation></ns1:geoLocation><ns1:siteProperty name="siteTypeCd">ST</ns1:siteProperty><ns1:siteProperty name="hucCd">02030103</ns1:siteProperty><ns1:siteProperty name="stateCd">34</ns1:siteProperty><ns1:siteProperty name="countyCd">34031</ns1:siteProperty></ns1:sourceInfo><ns1:variable ns1:oid="45807042"><ns1:variableCode network="NWIS" vocabulary="NWIS:UnitValues" default="true" variableID="45807042">00010</ns1:variableCode><ns1:variableName>Temperature, water, &amp;#176;C</ns1:variableName><ns1:variableDescription>Temperature, water, degrees Celsius</ns1:variableDescription><ns1:valueType>Derived Value</ns1:valueType><ns1:unit><ns1:unitCode>deg C</ns1:unitCode></ns1:unit><ns1:options><ns1:option name="Statistic" optionCode="00000"/></ns1:options><ns1:noDataValue>-999999.0</ns1:noDataValue></ns1:variable><ns1:values><ns1:value qualifiers="P" dateTime="2021-04-20T17:00:00.000-04:00">14.2</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T18:00:00.000-04:00">14.4</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T19:00:00.000-04:00">14.4</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T20:00:00.000-04:00">14.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T21:00:00.000-04:00">14.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T22:00:00.000-04:00">14.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-20T23:00:00.000-04:00">14.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T00:00:00.000-04:00">14.5</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T01:00:00.000-04:00">14.4</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T02:00:00.000-04:00">14.4</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T03:00:00.000-04:00">14.2</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T04:00:00.000-04:00">14.1</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T05:00:00.000-04:00">14.0</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T06:00:00.000-04:00">14.0</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T07:00:00.000-04:00">13.9</ns1:value><ns1:value qualifiers="P" dateTime="2021-04-21T08: ...

# %%
test1 = eval(json.dumps(xmltodict.parse(_r.text)))
wt_ts_raw = test1['ns1:timeSeriesResponse']['ns1:timeSeries']['ns1:values']
wt_ts_raw[0]['ns1:value'][0]
# Out:
# {'@qualifiers': 'P',
#  '@dateTime': '2021-04-20T17:00:00.000-04:00',
#  '#text': '14.2'}

# %%
# FOR GAGES WITH MULTIPLE INTAKES (RIGHT, CENTER, LEFT), WE NEED TO AVERAGE ALL OF THEM TOGETHER
wt_ts = {}
for i in range(0, len(wt_ts_raw)):
    for j in range(0,len(wt_ts_raw[i]['ns1:value']) - 1):
        if str(wt_ts_raw[i]['ns1:value'][j]['@dateTime']) in wt_ts.keys():
            wt_ts[str(wt_ts_raw[i]['ns1:value'][j]['@dateTime'])] += float(wt_ts_raw[i]['ns1:value'][j]['#text'])
        else:
            wt_ts[str(wt_ts_raw[i]['ns1:value'][j]['@dateTime'])] = float(wt_ts_raw[i]['ns1:value'][j]['#text'])

for i in wt_ts:
        wt_ts[i] = float(wt_ts[i]/len(wt_ts_raw))

wt_ts
# Out:
# {'2021-04-20T17:00:00.000-04:00': 13.799999999999999,
#  '2021-04-20T18:00:00.000-04:00': 13.9,
#  '2021-04-20T19:00:00.000-04:00': 13.933333333333332,
#  '2021-04-20T20:00:00.000-04:00': 14.033333333333333,
#  '2021-04-20T21:00:00.000-04:00': 14.066666666666668,
#  '2021-04-20T22:00:00.000-04:00': 14.133333333333335,
#  '2021-04-20T23:00:00.000-04:00': 14.133333333333335,
#  '2021-04-21T00:00:00.000-04:00': 14.133333333333335,
#  '2021-04-21T01:00:00.000-04:00': 14.066666666666668,
#  '2021-04-21T02:00:00.000-04:00': 14.1,
#  '2021-04-21T03:00:00.000-04:00': 13.966666666666667,
#  '2021-04-21T04:00:00.000-04:00': 13.866666666666667,
#  '2021-04-21T05:00:00.000-04:00': 13.799999999999999,
#  '2021-04-21T06:00:00.000-04:00': 13.733333333333334,
#  '2021-04-21T07:00:00.000-04:00': 13.666666666666666,
#  '2021-04-21T08:00:00.000-04:00': 13.666666666666666,
#  '2021-04-21T09:00:00.000-04:00': 13.733333333333334,
#  '2021-04-21T10:00:00.000-04:00': 13.866666666666667,
#  '2021-04-21T11:00:00.000-04:00': 13.933333333333332,
#  '2021-04-21T12:00:00.000-04:00': 14.1,
#  '2021-04-21T13:00:00.000-04:00': 14.266666666666666,
#  '2021-04-21T14:00:00.000-04:00': 14.366666666666667,
#  '2021-04-21T15:00:00.000-04:00': 14.4,
#  '2021-04-21T16:00:00.000-04:00': 14.433333333333332,
#  '2021-04-21T17:00:00.000-04:00': 14.433333333333332,
#  '2021-04-21T18:00:00.000-04:00': 14.4,
#  '2021-04-21T19:00:00.000-04:00': 14.4,
#  '2021-04-21T20:00:00.000-04:00': 14.299999999999999,
#  '2021-04-21T21:00:00.000-04:00': 14.233333333333334,
#  '2021-04-21T22:00:00.000-04:00': 14.066666666666668,
#  '2021-04-21T23:00:00.000-04:00': 13.966666666666669,
#  '2021-04-22T00:00:00.000-04:00': 13.766666666666666,
#  '2021-04-22T01:00:00.000-04:00': 13.6,
#  '2021-04-22T02:00:00.000-04:00': 13.433333333333332,
#  '2021-04-22T03:00:00.000-04:00': 13.166666666666666,
#  '2021-04-22T04:00:00.000-04:00': 13.0,
#  '2021-04-22T05:00:00.000-04:00': 12.866666666666665,
#  '2021-04-22T06:00:00.000-04:00': 12.700000000000001,
#  '2021-04-26T11:00:00.000-04:00': 12.833333333333334,
#  '2021-04-26T12:00:00.000-04:00': 13.033333333333331,
#  '2021-04-26T13:00:00.000-04:00': 13.233333333333333,
#  '2021-04-26T14:00:00.000-04:00': 13.366666666666667,
#  '2021-04-26T15:00:00.000-04:00': 13.566666666666668,
#  '2021-04-26T16:00:00.000-04:00': 13.633333333333333,
#  '2021-04-26T17:00:00.000-04:00': 13.733333333333333,
#  '2021-04-26T18:00:00.000-04:00': 13.666666666666666,
#  '2021-04-26T19:00:00.000-04:00': 13.666666666666666,
#  '2021-04-26T20:00:00.000-04:00': 13.633333333333333,
#  '2021-04-26T21:00:00.000-04:00': 13.666666666666666,
#  '2021-04-26T22:00:00.000-04:00': 13.666666666666666,
#  '2021-04-26T23:00:00.000-04:00': 13.633333333333333,
#  '2021-04-27T00:00:00.000-04:00': 13.6,
#  '2021-04-27T01:00:00.000-04:00': 13.5,
#  '2021-04-27T02:00:00.000-04:00': 13.466666666666667,
#  '2021-04-27T03:00:00.000-04:00': 13.300000000000002,
#  '2021-04-27T04:00:00.000-04:00': 13.166666666666666,
#  '2021-04-27T05:00:00.000-04:00': 13.033333333333333,
#  '2021-04-27T06:00:00.000-04:00': 12.933333333333335,
#  '2021-04-27T07:00:00.000-04:00': 12.799999999999999,
#  '2021-04-27T08:00:00.000-04:00': 12.700000000000001,
#  '2021-04-27T09:00:00.000-04:00': 12.633333333333333,
#  '2021-04-27T10:00:00.000-04:00': 12.6,
#  '2021-04-27T11:00:00.000-04:00': 12.6,
#  '2021-04-27T12:00:00.000-04:00': 12.766666666666667,
#  '2021-04-27T13:00:00.000-04:00': 13.033333333333333,
#  '2021-04-27T14:00:00.000-04:00': 13.300000000000002,
#  '2021-04-27T15:00:00.000-04:00': 13.533333333333333}

# %%
# SET UP TIME VARIABLES FOR WEATHER DATA
now_ep = int(time.time())
now_dt = datetime.now()
seconds_since_midnight = int((now_dt - now_dt.replace(hour=0, minute=0, second=0, microsecond=0)).total_seconds()) - 3600
day = 60*60*24
week = day * 7
last_week = now_ep - seconds_since_midnight - week

# %%
# GET LAST WEEK OF METEOROLOGICAL DATA

'''
Dark Sky is Best for Historical Data, however we cannot get new API keys so we might want to use a different service

API FORMATTING
"https://api.darksky.net/forecast/{}/{},{},{}".format([key], [latitude], [longitude], [time])

Gives daily min, max and hourly temperatures.
- sunrise/sunset
- precipitation intensity, probability, and type
- dewpoint, humidity, pressure, wind speed, visibility
- cloud cover (0-1), uvIndex, ozone
- nearest station
'''

locationt = (y, x)
ds_key = '1c78f26704537fe8484c246658d49fe1'

weather_arr = []
time_curr = last_week
for i in range(0,8):
    urlt = "https://api.darksky.net/forecast/{}/{},{},{}?exclude=currently,minutely,daily,flags,alerts".format(ds_key, locationt[0], locationt[1], time_curr)
    time_curr += day
    response = requests.request("GET", urlt)#, headers=headers)
    dt = eval(response.text)
    weather_arr.append(dt)

weather_arr
# Out:
# [{'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'data': [{'time': 1618891200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.75,
#      'apparentTemperature': 48.75,
#      'dewPoint': 43.33,
#      'humidity': 0.81,
#      'pressure': 1012.2,
#      'windSpeed': 1.39,
#      'windGust': 5.73,
#      'windBearing': 312,
#      'cloudCover': 0.09,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 369.2},
#     {'time': 1618894800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.1,
#      'apparentTemperature': 47.1,
#      'dewPoint': 42.79,
#      'humidity': 0.85,
#      'pressure': 1012.4,
#      'windSpeed': 1.77,
#      'windGust': 7.79,
#      'windBearing': 288,
#      'cloudCover': 0.01,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 365.7},
#     {'time': 1618898400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.89,
#      'apparentTemperature': 45.89,
#      'dewPoint': 41.56,
#      'humidity': 0.85,
#      'pressure': 1012.6,
#      'windSpeed': 1.63,
#      'windGust': 4.59,
#      'windBearing': 269,
#      'cloudCover': 0.03,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.6},
#     {'time': 1618902000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.15,
#      'apparentTemperature': 45.15,
#      'dewPoint': 40.96,
#      'humidity': 0.85,
#      'pressure': 1012.8,
#      'windSpeed': 1.84,
#      'windGust': 5.25,
#      'windBearing': 270,
#      'cloudCover': 0.04,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 359},
#     {'time': 1618905600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.01,
#      'apparentTemperature': 44.01,
#      'dewPoint': 40.16,
#      'humidity': 0.86,
#      'pressure': 1012.9,
#      'windSpeed': 1.75,
#      'windGust': 4.77,
#      'windBearing': 223,
#      'cloudCover': 0.07,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 353.6},
#     {'time': 1618909200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.68,
#      'apparentTemperature': 43.68,
#      'dewPoint': 40.22,
#      'humidity': 0.88,
#      'pressure': 1012.6,
#      'windSpeed': 1.72,
#      'windGust': 5.76,
#      'windBearing': 239,
#      'cloudCover': 0.07,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 351.1},
#     {'time': 1618912800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.83,
#      'apparentTemperature': 43.83,
#      'dewPoint': 39.57,
#      'humidity': 0.85,
#      'pressure': 1013,
#      'windSpeed': 2.19,
#      'windGust': 7.85,
#      'windBearing': 248,
#      'cloudCover': 0.08,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 350.3},
#     {'time': 1618916400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.35,
#      'apparentTemperature': 45.35,
#      'dewPoint': 41.8,
#      'humidity': 0.87,
#      'pressure': 1013.4,
#      'windSpeed': 2.52,
#      'windGust': 11.19,
#      'windBearing': 234,
#      'cloudCover': 0.1,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 351.3},
#     {'time': 1618920000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.12,
#      'apparentTemperature': 52.12,
#      'dewPoint': 43.94,
#      'humidity': 0.74,
#      'pressure': 1013.6,
#      'windSpeed': 5.5,
#      'windGust': 13.17,
#      'windBearing': 236,
#      'cloudCover': 0.02,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 354},
#     {'time': 1618923600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.93,
#      'apparentTemperature': 56.93,
#      'dewPoint': 44.38,
#      'humidity': 0.63,
#      'pressure': 1013.9,
#      'windSpeed': 5.27,
#      'windGust': 14.95,
#      'windBearing': 236,
#      'cloudCover': 0.06,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 356.3},
#     {'time': 1618927200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.95,
#      'apparentTemperature': 62.95,
#      'dewPoint': 42.3,
#      'humidity': 0.47,
#      'pressure': 1013.8,
#      'windSpeed': 7.23,
#      'windGust': 18.69,
#      'windBearing': 241,
#      'cloudCover': 0.07,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 356.3},
#     {'time': 1618930800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 67.93,
#      'apparentTemperature': 67.93,
#      'dewPoint': 39.78,
#      'humidity': 0.36,
#      'pressure': 1013.7,
#      'windSpeed': 9.88,
#      'windGust': 18.33,
#      'windBearing': 247,
#      'cloudCover': 0.08,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 359.7},
#     {'time': 1618934400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 70.15,
#      'apparentTemperature': 70.15,
#      'dewPoint': 38.41,
#      'humidity': 0.31,
#      'pressure': 1013.5,
#      'windSpeed': 10.75,
#      'windGust': 21.89,
#      'windBearing': 245,
#      'cloudCover': 0.08,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 361.5},
#     {'time': 1618938000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 72.07,
#      'apparentTemperature': 72.07,
#      'dewPoint': 38.12,
#      'humidity': 0.29,
#      'pressure': 1013,
#      'windSpeed': 10.71,
#      'windGust': 24.76,
#      'windBearing': 251,
#      'cloudCover': 0.12,
#      'uvIndex': 7,
#      'visibility': 10,
#      'ozone': 362},
#     {'time': 1618941600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.15,
#      'apparentTemperature': 74.15,
#      'dewPoint': 37.14,
#      'humidity': 0.26,
#      'pressure': 1012.4,
#      'windSpeed': 12.38,
#      'windGust': 22.85,
#      'windBearing': 235,
#      'cloudCover': 0.18,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 361.6},
#     {'time': 1618945200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.68,
#      'apparentTemperature': 74.68,
#      'dewPoint': 37.04,
#      'humidity': 0.26,
#      'pressure': 1012,
#      'windSpeed': 10.11,
#      'windGust': 24.92,
#      'windBearing': 243,
#      'cloudCover': 0.31,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 360.5},
#     {'time': 1618948800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.71,
#      'apparentTemperature': 74.71,
#      'dewPoint': 37.17,
#      'humidity': 0.26,
#      'pressure': 1011.5,
#      'windSpeed': 10.76,
#      'windGust': 22.45,
#      'windBearing': 245,
#      'cloudCover': 0.27,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 361.6},
#     {'time': 1618952400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 73.69,
#      'apparentTemperature': 73.69,
#      'dewPoint': 37.31,
#      'humidity': 0.27,
#      'pressure': 1011.2,
#      'windSpeed': 9.5,
#      'windGust': 22.84,
#      'windBearing': 226,
#      'cloudCover': 0.27,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 364.5},
#     {'time': 1618956000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 74.03,
#      'apparentTemperature': 74.03,
#      'dewPoint': 38.05,
#      'humidity': 0.27,
#      'pressure': 1011.2,
#      'windSpeed': 10.77,
#      'windGust': 21.06,
#      'windBearing': 221,
#      'cloudCover': 0.29,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 370.7},
#     {'time': 1618959600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 72.1,
#      'apparentTemperature': 72.1,
#      'dewPoint': 38.94,
#      'humidity': 0.3,
#      'pressure': 1010.9,
#      'windSpeed': 8.18,
#      'windGust': 19.92,
#      'windBearing': 222,
#      'cloudCover': 0.25,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 369.8},
#     {'time': 1618963200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 69.82,
#      'apparentTemperature': 69.82,
#      'dewPoint': 37.99,
#      'humidity': 0.31,
#      'pressure': 1011,
#      'windSpeed': 6.95,
#      'windGust': 17.87,
#      'windBearing': 206,
#      'cloudCover': 0.18,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 368.6},
#     {'time': 1618966800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 67.8,
#      'apparentTemperature': 67.8,
#      'dewPoint': 40.71,
#      'humidity': 0.37,
#      'pressure': 1011.8,
#      'windSpeed': 8.11,
#      'windGust': 22.39,
#      'windBearing': 203,
#      'cloudCover': 0.11,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 368.5},
#     {'time': 1618970400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 64.99,
#      'apparentTemperature': 64.99,
#      'dewPoint': 43.05,
#      'humidity': 0.45,
#      'pressure': 1012.3,
#      'windSpeed': 7.61,
#      'windGust': 25.32,
#      'windBearing': 204,
#      'cloudCover': 0.11,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.2},
#     {'time': 1618974000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.64,
#      'apparentTemperature': 62.64,
#      'dewPoint': 42.67,
#      'humidity': 0.48,
#      'pressure': 1012.3,
#      'windSpeed': 5.81,
#      'windGust': 22.84,
#      'windBearing': 212,
#      'cloudCover': 0.12,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 358}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Rain in the afternoon.',
#    'icon': 'rain',
#    'data': [{'time': 1618977600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.52,
#      'apparentTemperature': 60.52,
#      'dewPoint': 43.11,
#      'humidity': 0.53,
#      'pressure': 1012.1,
#      'windSpeed': 6.12,
#      'windGust': 21.4,
#      'windBearing': 193,
#      'cloudCover': 0.2,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360.9},
#     {'time': 1618981200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.42,
#      'apparentTemperature': 58.42,
#      'dewPoint': 42.66,
#      'humidity': 0.56,
#      'pressure': 1011.7,
#      'windSpeed': 4.8,
#      'windGust': 15.34,
#      'windBearing': 167,
#      'cloudCover': 0.22,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 362.1},
#     {'time': 1618984800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 57.38,
#      'apparentTemperature': 57.38,
#      'dewPoint': 42.13,
#      'humidity': 0.57,
#      'pressure': 1010.9,
#      'windSpeed': 2.57,
#      'windGust': 11.31,
#      'windBearing': 100,
#      'cloudCover': 0.19,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 363.8},
#     {'time': 1618988400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.76,
#      'apparentTemperature': 52.76,
#      'dewPoint': 41.75,
#      'humidity': 0.66,
#      'pressure': 1010.4,
#      'windSpeed': 2.48,
#      'windGust': 10.72,
#      'windBearing': 112,
#      'cloudCover': 0.15,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360.5},
#     {'time': 1618992000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51,
#      'apparentTemperature': 51,
#      'dewPoint': 42.14,
#      'humidity': 0.72,
#      'pressure': 1009.8,
#      'windSpeed': 2.73,
#      'windGust': 10.42,
#      'windBearing': 108,
#      'cloudCover': 0.13,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 358.4},
#     {'time': 1618995600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.37,
#      'apparentTemperature': 50.37,
#      'dewPoint': 41.93,
#      'humidity': 0.73,
#      'pressure': 1008.9,
#      'windSpeed': 2.16,
#      'windGust': 11.13,
#      'windBearing': 142,
#      'cloudCover': 0.36,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 356.7},
#     {'time': 1618999200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.29,
#      'apparentTemperature': 50.29,
#      'dewPoint': 42.62,
#      'humidity': 0.75,
#      'pressure': 1008.1,
#      'windSpeed': 3.86,
#      'windGust': 13.29,
#      'windBearing': 130,
#      'cloudCover': 0.6,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 353.6},
#     {'time': 1619002800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.76,
#      'apparentTemperature': 51.76,
#      'dewPoint': 42.62,
#      'humidity': 0.71,
#      'pressure': 1007.5,
#      'windSpeed': 2.52,
#      'windGust': 13.61,
#      'windBearing': 150,
#      'cloudCover': 0.77,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 353.5},
#     {'time': 1619006400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.67,
#      'apparentTemperature': 55.67,
#      'dewPoint': 43.16,
#      'humidity': 0.63,
#      'pressure': 1006.7,
#      'windSpeed': 4.2,
#      'windGust': 14.15,
#      'windBearing': 141,
#      'cloudCover': 0.62,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 354.6},
#     {'time': 1619010000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.1,
#      'apparentTemperature': 60.1,
#      'dewPoint': 42.87,
#      'humidity': 0.53,
#      'pressure': 1005.7,
#      'windSpeed': 6,
#      'windGust': 14.78,
#      'windBearing': 182,
#      'cloudCover': 0.47,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 358.3},
#     {'time': 1619013600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.86,
#      'apparentTemperature': 62.86,
#      'dewPoint': 44.19,
#      'humidity': 0.5,
#      'pressure': 1004.8,
#      'windSpeed': 7.95,
#      'windGust': 15.87,
#      'windBearing': 200,
#      'cloudCover': 0.69,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 361.8},
#     {'time': 1619017200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0002,
#      'precipProbability': 0.02,
#      'precipType': 'rain',
#      'temperature': 65.53,
#      'apparentTemperature': 65.53,
#      'dewPoint': 45.04,
#      'humidity': 0.48,
#      'pressure': 1003.7,
#      'windSpeed': 7.23,
#      'windGust': 16.58,
#      'windBearing': 195,
#      'cloudCover': 0.71,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 360.7},
#     {'time': 1619020800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 67.35,
#      'apparentTemperature': 67.35,
#      'dewPoint': 45.05,
#      'humidity': 0.45,
#      'pressure': 1002.5,
#      'windSpeed': 8.52,
#      'windGust': 16.96,
#      'windBearing': 213,
#      'cloudCover': 0.72,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 360.4},
#     {'time': 1619024400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.31,
#      'apparentTemperature': 68.31,
#      'dewPoint': 46.61,
#      'humidity': 0.46,
#      'pressure': 1000.8,
#      'windSpeed': 8.81,
#      'windGust': 19.27,
#      'windBearing': 220,
#      'cloudCover': 0.79,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 362.7},
#     {'time': 1619028000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 67.52,
#      'apparentTemperature': 67.52,
#      'dewPoint': 45.96,
#      'humidity': 0.46,
#      'pressure': 999.8,
#      'windSpeed': 11.17,
#      'windGust': 22.06,
#      'windBearing': 226,
#      'cloudCover': 0.85,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 363.6},
#     {'time': 1619031600,
#      'summary': 'Rain',
#      'icon': 'rain',
#      'precipIntensity': 0.0781,
#      'precipProbability': 0.88,
#      'precipType': 'rain',
#      'temperature': 55.81,
#      'apparentTemperature': 55.81,
#      'dewPoint': 43.04,
#      'humidity': 0.62,
#      'pressure': 1001.7,
#      'windSpeed': 13.9,
#      'windGust': 28.26,
#      'windBearing': 245,
#      'cloudCover': 0.93,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 367.6},
#     {'time': 1619035200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0.0081,
#      'precipProbability': 0.18,
#      'precipType': 'rain',
#      'temperature': 51.12,
#      'apparentTemperature': 51.12,
#      'dewPoint': 36.08,
#      'humidity': 0.56,
#      'pressure': 1002.7,
#      'windSpeed': 14.9,
#      'windGust': 27.46,
#      'windBearing': 338,
#      'cloudCover': 0.84,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 371.9},
#     {'time': 1619038800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.26,
#      'apparentTemperature': 41.4,
#      'dewPoint': 31.63,
#      'humidity': 0.54,
#      'pressure': 1004,
#      'windSpeed': 14,
#      'windGust': 26.3,
#      'windBearing': 314,
#      'cloudCover': 0.8,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 375},
#     {'time': 1619042400,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.36,
#      'apparentTemperature': 41.33,
#      'dewPoint': 30.27,
#      'humidity': 0.51,
#      'pressure': 1005.1,
#      'windSpeed': 14.73,
#      'windGust': 27.3,
#      'windBearing': 313,
#      'cloudCover': 0.77,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 377.2},
#     {'time': 1619046000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.6,
#      'apparentTemperature': 39.05,
#      'dewPoint': 28.53,
#      'humidity': 0.51,
#      'pressure': 1006,
#      'windSpeed': 14.85,
#      'windGust': 28.06,
#      'windBearing': 316,
#      'cloudCover': 0.82,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 379.5},
#     {'time': 1619049600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.63,
#      'apparentTemperature': 36.34,
#      'dewPoint': 27.18,
#      'humidity': 0.52,
#      'pressure': 1006.9,
#      'windSpeed': 15.52,
#      'windGust': 26.52,
#      'windBearing': 323,
#      'cloudCover': 0.84,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 385.9},
#     {'time': 1619053200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 41.97,
#      'apparentTemperature': 34.6,
#      'dewPoint': 24.51,
#      'humidity': 0.5,
#      'pressure': 1008.1,
#      'windSpeed': 14.16,
#      'windGust': 26.24,
#      'windBearing': 323,
#      'cloudCover': 0.63,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 393.8},
#     {'time': 1619056800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 41.05,
#      'apparentTemperature': 33.54,
#      'dewPoint': 23.29,
#      'humidity': 0.49,
#      'pressure': 1009.2,
#      'windSpeed': 13.85,
#      'windGust': 26.94,
#      'windBearing': 322,
#      'cloudCover': 0.53,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 398.8},
#     {'time': 1619060400,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 39.82,
#      'apparentTemperature': 32.46,
#      'dewPoint': 22.97,
#      'humidity': 0.51,
#      'pressure': 1009.3,
#      'windSpeed': 12.42,
#      'windGust': 24.26,
#      'windBearing': 316,
#      'cloudCover': 0.37,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 402.2}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'data': [{'time': 1619064000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 38.49,
#      'apparentTemperature': 30.92,
#      'dewPoint': 22.95,
#      'humidity': 0.53,
#      'pressure': 1009.6,
#      'windSpeed': 12.06,
#      'windGust': 24.34,
#      'windBearing': 317,
#      'cloudCover': 0.34,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 405.4},
#     {'time': 1619067600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 37.08,
#      'apparentTemperature': 29.83,
#      'dewPoint': 21.42,
#      'humidity': 0.53,
#      'pressure': 1009.6,
#      'windSpeed': 10.43,
#      'windGust': 28.41,
#      'windBearing': 301,
#      'cloudCover': 0.25,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 405.4},
#     {'time': 1619071200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 36.59,
#      'apparentTemperature': 29.48,
#      'dewPoint': 21.52,
#      'humidity': 0.54,
#      'pressure': 1009.4,
#      'windSpeed': 9.85,
#      'windGust': 23.44,
#      'windBearing': 298,
#      'cloudCover': 0.13,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 408.2},
#     {'time': 1619074800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 36.12,
#      'apparentTemperature': 28.62,
#      'dewPoint': 21.76,
#      'humidity': 0.56,
#      'pressure': 1009.3,
#      'windSpeed': 10.45,
#      'windGust': 23.88,
#      'windBearing': 297,
#      'cloudCover': 0.05,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 414.7},
#     {'time': 1619078400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 36.04,
#      'apparentTemperature': 29.09,
#      'dewPoint': 21.99,
#      'humidity': 0.56,
#      'pressure': 1009.6,
#      'windSpeed': 9.25,
#      'windGust': 26.44,
#      'windBearing': 282,
#      'cloudCover': 0.07,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 415.3},
#     {'time': 1619082000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 35.95,
#      'apparentTemperature': 29.24,
#      'dewPoint': 22.61,
#      'humidity': 0.58,
#      'pressure': 1009.5,
#      'windSpeed': 8.76,
#      'windGust': 23.11,
#      'windBearing': 282,
#      'cloudCover': 0.38,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 416.6},
#     {'time': 1619085600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 35.7,
#      'apparentTemperature': 28.04,
#      'dewPoint': 20.01,
#      'humidity': 0.52,
#      'pressure': 1009.8,
#      'windSpeed': 10.61,
#      'windGust': 23.95,
#      'windBearing': 279,
#      'cloudCover': 0.44,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 418.6},
#     {'time': 1619089200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 34.85,
#      'apparentTemperature': 26.47,
#      'dewPoint': 16.14,
#      'humidity': 0.46,
#      'pressure': 1010.8,
#      'windSpeed': 11.74,
#      'windGust': 22.1,
#      'windBearing': 297,
#      'cloudCover': 0.26,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 420.7},
#     {'time': 1619092800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 36.28,
#      'apparentTemperature': 27.73,
#      'dewPoint': 15.21,
#      'humidity': 0.42,
#      'pressure': 1011.3,
#      'windSpeed': 13.14,
#      'windGust': 24.6,
#      'windBearing': 290,
#      'cloudCover': 0.1,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 421.4},
#     {'time': 1619096400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 38.11,
#      'apparentTemperature': 30.48,
#      'dewPoint': 15.51,
#      'humidity': 0.39,
#      'pressure': 1011.2,
#      'windSpeed': 11.99,
#      'windGust': 24.98,
#      'windBearing': 302,
#      'cloudCover': 0.24,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 423.5},
#     {'time': 1619100000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.13,
#      'apparentTemperature': 31.98,
#      'dewPoint': 14.36,
#      'humidity': 0.35,
#      'pressure': 1011.5,
#      'windSpeed': 15.05,
#      'windGust': 28.56,
#      'windBearing': 295,
#      'cloudCover': 0.58,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 422.9},
#     {'time': 1619103600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 42.86,
#      'apparentTemperature': 35.27,
#      'dewPoint': 14.68,
#      'humidity': 0.32,
#      'pressure': 1011.7,
#      'windSpeed': 15.83,
#      'windGust': 26.94,
#      'windBearing': 296,
#      'cloudCover': 0.61,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 425.2},
#     {'time': 1619107200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.61,
#      'apparentTemperature': 36.36,
#      'dewPoint': 14.56,
#      'humidity': 0.3,
#      'pressure': 1011.5,
#      'windSpeed': 15.36,
#      'windGust': 31.2,
#      'windBearing': 284,
#      'cloudCover': 0.79,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 426.5},
#     {'time': 1619110800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.47,
#      'apparentTemperature': 37.21,
#      'dewPoint': 15.12,
#      'humidity': 0.3,
#      'pressure': 1011.1,
#      'windSpeed': 16.3,
#      'windGust': 27.21,
#      'windBearing': 289,
#      'cloudCover': 0.85,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 425.5},
#     {'time': 1619114400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.44,
#      'apparentTemperature': 40.17,
#      'dewPoint': 15.07,
#      'humidity': 0.28,
#      'pressure': 1011.3,
#      'windSpeed': 14.65,
#      'windGust': 26.23,
#      'windBearing': 294,
#      'cloudCover': 0.9,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 430.4},
#     {'time': 1619118000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.25,
#      'apparentTemperature': 41.33,
#      'dewPoint': 15.56,
#      'humidity': 0.28,
#      'pressure': 1011.1,
#      'windSpeed': 14.19,
#      'windGust': 26.1,
#      'windBearing': 287,
#      'cloudCover': 0.92,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 432.7},
#     {'time': 1619121600,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.29,
#      'apparentTemperature': 42.07,
#      'dewPoint': 16.2,
#      'humidity': 0.27,
#      'pressure': 1010.8,
#      'windSpeed': 16.57,
#      'windGust': 27.06,
#      'windBearing': 289,
#      'cloudCover': 0.94,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 435.4},
#     {'time': 1619125200,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.79,
#      'apparentTemperature': 42.37,
#      'dewPoint': 17.78,
#      'humidity': 0.3,
#      'pressure': 1011.1,
#      'windSpeed': 12.94,
#      'windGust': 26.49,
#      'windBearing': 291,
#      'cloudCover': 0.95,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 441},
#     {'time': 1619128800,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.96,
#      'apparentTemperature': 42.37,
#      'dewPoint': 18.49,
#      'humidity': 0.31,
#      'pressure': 1011.5,
#      'windSpeed': 13.67,
#      'windGust': 28.34,
#      'windBearing': 289,
#      'cloudCover': 0.92,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 444.5},
#     {'time': 1619132400,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.45,
#      'apparentTemperature': 41.06,
#      'dewPoint': 18.06,
#      'humidity': 0.32,
#      'pressure': 1012.2,
#      'windSpeed': 11.67,
#      'windGust': 25.72,
#      'windBearing': 298,
#      'cloudCover': 0.89,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 446.3},
#     {'time': 1619136000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.29,
#      'apparentTemperature': 39.75,
#      'dewPoint': 18.29,
#      'humidity': 0.34,
#      'pressure': 1012.7,
#      'windSpeed': 11.23,
#      'windGust': 27.2,
#      'windBearing': 301,
#      'cloudCover': 0.81,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 447.5},
#     {'time': 1619139600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.16,
#      'apparentTemperature': 39.19,
#      'dewPoint': 18.97,
#      'humidity': 0.36,
#      'pressure': 1013.8,
#      'windSpeed': 9.03,
#      'windGust': 24.52,
#      'windBearing': 296,
#      'cloudCover': 0.41,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 450.2},
#     {'time': 1619143200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.35,
#      'apparentTemperature': 38.64,
#      'dewPoint': 19.15,
#      'humidity': 0.38,
#      'pressure': 1014.5,
#      'windSpeed': 8.04,
#      'windGust': 22.18,
#      'windBearing': 292,
#      'cloudCover': 0.23,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 452.9},
#     {'time': 1619146800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 41.93,
#      'apparentTemperature': 39.34,
#      'dewPoint': 19.84,
#      'humidity': 0.41,
#      'pressure': 1014.8,
#      'windSpeed': 4.24,
#      'windGust': 22.32,
#      'windBearing': 276,
#      'cloudCover': 0.25,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 456.3}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'data': [{'time': 1619150400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.13,
#      'apparentTemperature': 37.23,
#      'dewPoint': 21.09,
#      'humidity': 0.46,
#      'pressure': 1015,
#      'windSpeed': 4.27,
#      'windGust': 23.5,
#      'windBearing': 276,
#      'cloudCover': 0.27,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 458.3},
#     {'time': 1619154000,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.92,
#      'apparentTemperature': 35.28,
#      'dewPoint': 23.44,
#      'humidity': 0.49,
#      'pressure': 1015.4,
#      'windSpeed': 8.88,
#      'windGust': 22.3,
#      'windBearing': 285,
#      'cloudCover': 0.47,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 448.9},
#     {'time': 1619157600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.67,
#      'apparentTemperature': 35.31,
#      'dewPoint': 24.63,
#      'humidity': 0.53,
#      'pressure': 1015.3,
#      'windSpeed': 8.16,
#      'windGust': 20,
#      'windBearing': 290,
#      'cloudCover': 0.35,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 445.2},
#     {'time': 1619161200,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 40.42,
#      'apparentTemperature': 34.69,
#      'dewPoint': 25.75,
#      'humidity': 0.56,
#      'pressure': 1015.7,
#      'windSpeed': 8.83,
#      'windGust': 22.46,
#      'windBearing': 306,
#      'cloudCover': 0.52,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 444.6},
#     {'time': 1619164800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 38.54,
#      'apparentTemperature': 33.04,
#      'dewPoint': 23.55,
#      'humidity': 0.55,
#      'pressure': 1016.3,
#      'windSpeed': 7.56,
#      'windGust': 20.6,
#      'windBearing': 296,
#      'cloudCover': 0.5,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 437.2},
#     {'time': 1619168400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 38.01,
#      'apparentTemperature': 32.84,
#      'dewPoint': 21.79,
#      'humidity': 0.52,
#      'pressure': 1016.6,
#      'windSpeed': 6.82,
#      'windGust': 24.09,
#      'windBearing': 285,
#      'cloudCover': 0.05,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 426.4},
#     {'time': 1619172000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 37.58,
#      'apparentTemperature': 32.44,
#      'dewPoint': 21.88,
#      'humidity': 0.53,
#      'pressure': 1016.9,
#      'windSpeed': 6.67,
#      'windGust': 22.87,
#      'windBearing': 281,
#      'cloudCover': 0.03,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 417},
#     {'time': 1619175600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 38,
#      'apparentTemperature': 33.05,
#      'dewPoint': 21.68,
#      'humidity': 0.51,
#      'pressure': 1017.3,
#      'windSpeed': 6.48,
#      'windGust': 21.43,
#      'windBearing': 271,
#      'cloudCover': 0.03,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 414.1},
#     {'time': 1619179200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 41.46,
#      'apparentTemperature': 36.4,
#      'dewPoint': 21.4,
#      'humidity': 0.44,
#      'pressure': 1017.7,
#      'windSpeed': 7.93,
#      'windGust': 22.17,
#      'windBearing': 277,
#      'cloudCover': 0.01,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 413.9},
#     {'time': 1619182800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.01,
#      'apparentTemperature': 39.87,
#      'dewPoint': 19.96,
#      'humidity': 0.37,
#      'pressure': 1017.7,
#      'windSpeed': 9.96,
#      'windGust': 21.15,
#      'windBearing': 250,
#      'cloudCover': 0.01,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 414},
#     {'time': 1619186400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.69,
#      'apparentTemperature': 43.01,
#      'dewPoint': 20.36,
#      'humidity': 0.34,
#      'pressure': 1017.5,
#      'windSpeed': 10.46,
#      'windGust': 25.07,
#      'windBearing': 314,
#      'cloudCover': 0.01,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 410.5},
#     {'time': 1619190000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.26,
#      'apparentTemperature': 51.26,
#      'dewPoint': 19.42,
#      'humidity': 0.28,
#      'pressure': 1016.9,
#      'windSpeed': 11.2,
#      'windGust': 22.9,
#      'windBearing': 286,
#      'cloudCover': 0.02,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 406.7},
#     {'time': 1619193600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.19,
#      'apparentTemperature': 54.19,
#      'dewPoint': 20.41,
#      'humidity': 0.26,
#      'pressure': 1016,
#      'windSpeed': 12.92,
#      'windGust': 24.09,
#      'windBearing': 268,
#      'cloudCover': 0.04,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 403.2},
#     {'time': 1619197200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.37,
#      'apparentTemperature': 56.37,
#      'dewPoint': 20.3,
#      'humidity': 0.24,
#      'pressure': 1014.8,
#      'windSpeed': 12.69,
#      'windGust': 23.03,
#      'windBearing': 270,
#      'cloudCover': 0.04,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 405.6},
#     {'time': 1619200800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 59.74,
#      'apparentTemperature': 59.74,
#      'dewPoint': 20.98,
#      'humidity': 0.22,
#      'pressure': 1014.1,
#      'windSpeed': 12.83,
#      'windGust': 25.6,
#      'windBearing': 275,
#      'cloudCover': 0.04,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 408},
#     {'time': 1619204400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 61.87,
#      'apparentTemperature': 61.87,
#      'dewPoint': 20.22,
#      'humidity': 0.2,
#      'pressure': 1013.5,
#      'windSpeed': 13.3,
#      'windGust': 26.16,
#      'windBearing': 274,
#      'cloudCover': 0.05,
#      'uvIndex': 4,
#      'visibility': 10,
#      'ozone': 409.2},
#     {'time': 1619208000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 63.59,
#      'apparentTemperature': 63.59,
#      'dewPoint': 20.44,
#      'humidity': 0.19,
#      'pressure': 1013,
#      'windSpeed': 13.45,
#      'windGust': 24.72,
#      'windBearing': 278,
#      'cloudCover': 0.06,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 407.8},
#     {'time': 1619211600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 64.48,
#      'apparentTemperature': 64.48,
#      'dewPoint': 20.62,
#      'humidity': 0.18,
#      'pressure': 1012.8,
#      'windSpeed': 13.56,
#      'windGust': 27.68,
#      'windBearing': 283,
#      'cloudCover': 0.07,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 412.1},
#     {'time': 1619215200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 64.87,
#      'apparentTemperature': 64.87,
#      'dewPoint': 20.78,
#      'humidity': 0.18,
#      'pressure': 1012.8,
#      'windSpeed': 11.89,
#      'windGust': 23.67,
#      'windBearing': 304,
#      'cloudCover': 0.06,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 411.5},
#     {'time': 1619218800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 63.71,
#      'apparentTemperature': 63.71,
#      'dewPoint': 22.56,
#      'humidity': 0.21,
#      'pressure': 1013,
#      'windSpeed': 9.61,
#      'windGust': 22.79,
#      'windBearing': 251,
#      'cloudCover': 0.04,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 412},
#     {'time': 1619222400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 61.17,
#      'apparentTemperature': 61.17,
#      'dewPoint': 23.62,
#      'humidity': 0.24,
#      'pressure': 1013.5,
#      'windSpeed': 5.68,
#      'windGust': 18.15,
#      'windBearing': 268,
#      'cloudCover': 0.01,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 409.1},
#     {'time': 1619226000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 57.18,
#      'apparentTemperature': 57.18,
#      'dewPoint': 24.86,
#      'humidity': 0.29,
#      'pressure': 1014.3,
#      'windSpeed': 3.32,
#      'windGust': 12.75,
#      'windBearing': 271,
#      'cloudCover': 0.04,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 405.5},
#     {'time': 1619229600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.83,
#      'apparentTemperature': 54.83,
#      'dewPoint': 27.88,
#      'humidity': 0.35,
#      'pressure': 1014.9,
#      'windSpeed': 4.88,
#      'windGust': 12.07,
#      'windBearing': 227,
#      'cloudCover': 0.19,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 401.3},
#     {'time': 1619233200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.67,
#      'apparentTemperature': 52.67,
#      'dewPoint': 28.14,
#      'humidity': 0.39,
#      'pressure': 1015.1,
#      'windSpeed': 2.56,
#      'windGust': 11.07,
#      'windBearing': 262,
#      'cloudCover': 0.19,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 408.5}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'data': [{'time': 1619236800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 50.42,
#      'apparentTemperature': 50.42,
#      'dewPoint': 29.59,
#      'humidity': 0.45,
#      'pressure': 1015.2,
#      'windSpeed': 3.01,
#      'windGust': 11.89,
#      'windBearing': 239,
#      'cloudCover': 0.23,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 413},
#     {'time': 1619240400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.92,
#      'apparentTemperature': 48.2,
#      'dewPoint': 31.08,
#      'humidity': 0.5,
#      'pressure': 1015.2,
#      'windSpeed': 3.28,
#      'windGust': 12.83,
#      'windBearing': 265,
#      'cloudCover': 0.09,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 410.8},
#     {'time': 1619244000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.5,
#      'apparentTemperature': 46.52,
#      'dewPoint': 30.82,
#      'humidity': 0.52,
#      'pressure': 1015.4,
#      'windSpeed': 3.35,
#      'windGust': 13.2,
#      'windBearing': 257,
#      'cloudCover': 0.15,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 404.3},
#     {'time': 1619247600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 47.61,
#      'apparentTemperature': 45.66,
#      'dewPoint': 30.39,
#      'humidity': 0.51,
#      'pressure': 1015.8,
#      'windSpeed': 4.62,
#      'windGust': 12.1,
#      'windBearing': 229,
#      'cloudCover': 0.07,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 404.7},
#     {'time': 1619251200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.55,
#      'apparentTemperature': 43.07,
#      'dewPoint': 30.84,
#      'humidity': 0.56,
#      'pressure': 1016.2,
#      'windSpeed': 4.88,
#      'windGust': 11.83,
#      'windBearing': 251,
#      'cloudCover': 0.05,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 403.9},
#     {'time': 1619254800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 45.36,
#      'apparentTemperature': 45.36,
#      'dewPoint': 30.95,
#      'humidity': 0.57,
#      'pressure': 1016.2,
#      'windSpeed': 2.99,
#      'windGust': 12.21,
#      'windBearing': 272,
#      'cloudCover': 0.14,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 403.6},
#     {'time': 1619258400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.34,
#      'apparentTemperature': 44.34,
#      'dewPoint': 31.13,
#      'humidity': 0.6,
#      'pressure': 1016.4,
#      'windSpeed': 2.39,
#      'windGust': 11.21,
#      'windBearing': 321,
#      'cloudCover': 0.06,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 399.4},
#     {'time': 1619262000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.27,
#      'apparentTemperature': 43.96,
#      'dewPoint': 31.57,
#      'humidity': 0.56,
#      'pressure': 1017,
#      'windSpeed': 4.81,
#      'windGust': 11.67,
#      'windBearing': 224,
#      'cloudCover': 0.06,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 389.5},
#     {'time': 1619265600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.11,
#      'apparentTemperature': 53.11,
#      'dewPoint': 30.22,
#      'humidity': 0.41,
#      'pressure': 1017.4,
#      'windSpeed': 5.06,
#      'windGust': 17.81,
#      'windBearing': 251,
#      'cloudCover': 0.05,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 395},
#     {'time': 1619269200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.13,
#      'apparentTemperature': 58.13,
#      'dewPoint': 29.68,
#      'humidity': 0.34,
#      'pressure': 1017.4,
#      'windSpeed': 3.38,
#      'windGust': 17.55,
#      'windBearing': 304,
#      'cloudCover': 0.13,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 392.3},
#     {'time': 1619272800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.62,
#      'apparentTemperature': 62.62,
#      'dewPoint': 30.2,
#      'humidity': 0.29,
#      'pressure': 1017.6,
#      'windSpeed': 6.02,
#      'windGust': 13.52,
#      'windBearing': 313,
#      'cloudCover': 0.19,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 390.9},
#     {'time': 1619276400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 65.37,
#      'apparentTemperature': 65.37,
#      'dewPoint': 29.24,
#      'humidity': 0.26,
#      'pressure': 1017.4,
#      'windSpeed': 5.72,
#      'windGust': 12.09,
#      'windBearing': 299,
#      'cloudCover': 0.17,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 387.4},
#     {'time': 1619280000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 67.3,
# ...
#      'visibility': 10,
#      'ozone': 398.1},
#     {'time': 1619452800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.13,
#      'apparentTemperature': 51.13,
#      'dewPoint': 22.09,
#      'humidity': 0.32,
#      'pressure': 1017.5,
#      'windSpeed': 13.47,
#      'windGust': 22.43,
#      'windBearing': 297,
#      'cloudCover': 0.04,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 395.6},
#     {'time': 1619456400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 53.55,
#      'apparentTemperature': 53.55,
#      'dewPoint': 21.96,
#      'humidity': 0.29,
#      'pressure': 1017.1,
#      'windSpeed': 10.86,
#      'windGust': 21.19,
#      'windBearing': 313,
#      'cloudCover': 0.03,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 392.5},
#     {'time': 1619460000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 56.72,
#      'apparentTemperature': 56.72,
#      'dewPoint': 20.68,
#      'humidity': 0.24,
#      'pressure': 1017,
#      'windSpeed': 12.3,
#      'windGust': 22.83,
#      'windBearing': 319,
#      'cloudCover': 0.03,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 387.3},
#     {'time': 1619463600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.94,
#      'apparentTemperature': 58.94,
#      'dewPoint': 19.35,
#      'humidity': 0.21,
#      'pressure': 1016.5,
#      'windSpeed': 12.06,
#      'windGust': 24.25,
#      'windBearing': 314,
#      'cloudCover': 0.01,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 387.5},
#     {'time': 1619467200,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 59.73,
#      'apparentTemperature': 59.73,
#      'dewPoint': 18.14,
#      'humidity': 0.2,
#      'pressure': 1016.4,
#      'windSpeed': 12.57,
#      'windGust': 23.5,
#      'windBearing': 316,
#      'cloudCover': 0.01,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 388.7},
#     {'time': 1619470800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 59.44,
#      'apparentTemperature': 59.44,
#      'dewPoint': 16.84,
#      'humidity': 0.19,
#      'pressure': 1016,
#      'windSpeed': 12.29,
#      'windGust': 24.64,
#      'windBearing': 309,
#      'cloudCover': 0.01,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 388.1},
#     {'time': 1619474400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.5,
#      'apparentTemperature': 60.5,
#      'dewPoint': 16.6,
#      'humidity': 0.18,
#      'pressure': 1016.5,
#      'windSpeed': 11.19,
#      'windGust': 22,
#      'windBearing': 314,
#      'cloudCover': 0.01,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 388.5},
#     {'time': 1619478000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.51,
#      'apparentTemperature': 58.51,
#      'dewPoint': 16.47,
#      'humidity': 0.19,
#      'pressure': 1017,
#      'windSpeed': 9.92,
#      'windGust': 20.6,
#      'windBearing': 311,
#      'cloudCover': 0.01,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 387.1},
#     {'time': 1619481600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.87,
#      'apparentTemperature': 55.87,
#      'dewPoint': 16.99,
#      'humidity': 0.21,
#      'pressure': 1017.8,
#      'windSpeed': 8.04,
#      'windGust': 21.36,
#      'windBearing': 308,
#      'cloudCover': 0,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 384.7},
#     {'time': 1619485200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 54.05,
#      'apparentTemperature': 54.05,
#      'dewPoint': 16.25,
#      'humidity': 0.22,
#      'pressure': 1018.8,
#      'windSpeed': 6.6,
#      'windGust': 22.19,
#      'windBearing': 307,
#      'cloudCover': 0.01,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 382.5},
#     {'time': 1619488800,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 51.96,
#      'apparentTemperature': 51.96,
#      'dewPoint': 16.58,
#      'humidity': 0.24,
#      'pressure': 1019.1,
#      'windSpeed': 6.57,
#      'windGust': 21.93,
#      'windBearing': 307,
#      'cloudCover': 0.03,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 379.4},
#     {'time': 1619492400,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 49.91,
#      'apparentTemperature': 49.25,
#      'dewPoint': 16.33,
#      'humidity': 0.26,
#      'pressure': 1019.5,
#      'windSpeed': 3.38,
#      'windGust': 20.34,
#      'windBearing': 328,
#      'cloudCover': 0.04,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 377.5}]},
#   'offset': -4},
#  {'latitude': 40.89638889000001,
#   'longitude': -74.2691667,
#   'timezone': 'America/New_York',
#   'hourly': {'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'data': [{'time': 1619496000,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 48.07,
#      'apparentTemperature': 47.46,
#      'dewPoint': 18.28,
#      'humidity': 0.3,
#      'pressure': 1019.6,
#      'windSpeed': 3.04,
#      'windGust': 17.2,
#      'windBearing': 333,
#      'cloudCover': 0.03,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 376.2},
#     {'time': 1619499600,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 46.49,
#      'apparentTemperature': 46.49,
#      'dewPoint': 18.61,
#      'humidity': 0.33,
#      'pressure': 1019.8,
#      'windSpeed': 2.75,
#      'windGust': 12.53,
#      'windBearing': 334,
#      'cloudCover': 0.02,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 376.1},
#     {'time': 1619503200,
#      'summary': 'Clear',
#      'icon': 'clear-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 44.29,
#      'apparentTemperature': 42.58,
#      'dewPoint': 19.51,
#      'humidity': 0.37,
#      'pressure': 1019.7,
#      'windSpeed': 3.65,
#      'windGust': 7.88,
#      'windBearing': 326,
#      'cloudCover': 0.06,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 374.1},
#     {'time': 1619506800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.75,
#      'apparentTemperature': 43.75,
#      'dewPoint': 22.01,
#      'humidity': 0.42,
#      'pressure': 1019.9,
#      'windSpeed': 2.05,
#      'windGust': 7.42,
#      'windBearing': 322,
#      'cloudCover': 0.39,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 372.2},
#     {'time': 1619510400,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.69,
#      'apparentTemperature': 42.24,
#      'dewPoint': 23.34,
#      'humidity': 0.44,
#      'pressure': 1020.3,
#      'windSpeed': 3.28,
#      'windGust': 7.65,
#      'windBearing': 279,
#      'cloudCover': 0.53,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 369.9},
#     {'time': 1619514000,
#      'summary': 'Overcast',
#      'icon': 'cloudy',
#      'precipIntensity': 0.0002,
#      'precipProbability': 0.03,
#      'precipType': 'rain',
#      'temperature': 43.67,
#      'apparentTemperature': 43.67,
#      'dewPoint': 26.42,
#      'humidity': 0.5,
#      'pressure': 1020.4,
#      'windSpeed': 2.24,
#      'windGust': 10.5,
#      'windBearing': 328,
#      'cloudCover': 0.88,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 369.5},
#     {'time': 1619517600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.42,
#      'apparentTemperature': 43.42,
#      'dewPoint': 29.17,
#      'humidity': 0.57,
#      'pressure': 1020.5,
#      'windSpeed': 1.69,
#      'windGust': 8.49,
#      'windBearing': 344,
#      'cloudCover': 0.68,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 366.9},
#     {'time': 1619521200,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 43.87,
#      'apparentTemperature': 43.87,
#      'dewPoint': 29.35,
#      'humidity': 0.56,
#      'pressure': 1020.7,
#      'windSpeed': 1.17,
#      'windGust': 5.81,
#      'windBearing': 49,
#      'cloudCover': 0.59,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 366.2},
#     {'time': 1619524800,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0.0012,
#      'precipProbability': 0.12,
#      'precipType': 'rain',
#      'temperature': 47.1,
#      'apparentTemperature': 47.1,
#      'dewPoint': 25.63,
#      'humidity': 0.43,
#      'pressure': 1020.6,
#      'windSpeed': 1.01,
#      'windGust': 3.76,
#      'windBearing': 227,
#      'cloudCover': 0.21,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 366.5},
#     {'time': 1619528400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 49.88,
#      'apparentTemperature': 49.88,
#      'dewPoint': 24.28,
#      'humidity': 0.36,
#      'pressure': 1020.7,
#      'windSpeed': 1.35,
#      'windGust': 3.68,
#      'windBearing': 198,
#      'cloudCover': 0.22,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 364.8},
#     {'time': 1619532000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 52.4,
#      'apparentTemperature': 52.4,
#      'dewPoint': 23.72,
#      'humidity': 0.32,
#      'pressure': 1020,
#      'windSpeed': 2.21,
#      'windGust': 4.98,
#      'windBearing': 145,
#      'cloudCover': 0.3,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 363.8},
#     {'time': 1619535600,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 55.59,
#      'apparentTemperature': 55.59,
#      'dewPoint': 24.79,
#      'humidity': 0.3,
#      'pressure': 1019.2,
#      'windSpeed': 2.26,
#      'windGust': 5.12,
#      'windBearing': 156,
#      'cloudCover': 0.32,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 362.6},
#     {'time': 1619539200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 58.64,
#      'apparentTemperature': 58.64,
#      'dewPoint': 23.67,
#      'humidity': 0.26,
#      'pressure': 1018.1,
#      'windSpeed': 4.32,
#      'windGust': 8.73,
#      'windBearing': 147,
#      'cloudCover': 0.63,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 361.8},
#     {'time': 1619542800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 62.01,
#      'apparentTemperature': 62.01,
#      'dewPoint': 22.38,
#      'humidity': 0.22,
#      'pressure': 1017.1,
#      'windSpeed': 6.69,
#      'windGust': 9.57,
#      'windBearing': 177,
#      'cloudCover': 0.49,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 360.9},
#     {'time': 1619546400,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 63.5,
#      'apparentTemperature': 63.5,
#      'dewPoint': 26.05,
#      'humidity': 0.24,
#      'pressure': 1016.3,
#      'windSpeed': 7.31,
#      'windGust': 10.09,
#      'windBearing': 167,
#      'cloudCover': 0.22,
#      'uvIndex': 6,
#      'visibility': 10,
#      'ozone': 359.6},
#     {'time': 1619550000,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 65.76,
#      'apparentTemperature': 65.76,
#      'dewPoint': 25.62,
#      'humidity': 0.22,
#      'pressure': 1015.2,
#      'windSpeed': 4.28,
#      'windGust': 9.98,
#      'windBearing': 175,
#      'cloudCover': 0.08,
#      'uvIndex': 5,
#      'visibility': 10,
#      'ozone': 360.4},
#     {'time': 1619553600,
#      'summary': 'Clear',
#      'icon': 'clear-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.08,
#      'apparentTemperature': 68.08,
#      'dewPoint': 28.5,
#      'humidity': 0.23,
#      'pressure': 1014.4,
#      'windSpeed': 3.63,
#      'windGust': 9.95,
#      'windBearing': 188,
#      'cloudCover': 0.22,
#      'uvIndex': 3,
#      'visibility': 10,
#      'ozone': 359.7},
#     {'time': 1619557200,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 69.28,
#      'apparentTemperature': 69.28,
#      'dewPoint': 31.07,
#      'humidity': 0.24,
#      'pressure': 1014.3,
#      'windSpeed': 3.2,
#      'windGust': 10.25,
#      'windBearing': 199,
#      'cloudCover': 0.54,
#      'uvIndex': 2,
#      'visibility': 10,
#      'ozone': 360.9},
#     {'time': 1619560800,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 70.15,
#      'apparentTemperature': 70.15,
#      'dewPoint': 35.99,
#      'humidity': 0.29,
#      'pressure': 1014.1,
#      'windSpeed': 4.27,
#      'windGust': 9.76,
#      'windBearing': 184,
#      'cloudCover': 0.37,
#      'uvIndex': 1,
#      'visibility': 10,
#      'ozone': 362.4},
#     {'time': 1619564400,
#      'summary': 'Partly Cloudy',
#      'icon': 'partly-cloudy-day',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 68.02,
#      'apparentTemperature': 68.02,
#      'dewPoint': 40.64,
#      'humidity': 0.37,
#      'pressure': 1014.1,
#      'windSpeed': 4.76,
#      'windGust': 7.86,
#      'windBearing': 175,
#      'cloudCover': 0.55,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 361.8},
#     {'time': 1619568000,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 63.58,
#      'apparentTemperature': 63.58,
#      'dewPoint': 42.77,
#      'humidity': 0.47,
#      'pressure': 1014.2,
#      'windSpeed': 3.93,
#      'windGust': 6.59,
#      'windBearing': 165,
#      'cloudCover': 0.7,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 361.7},
#     {'time': 1619571600,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 60.71,
#      'apparentTemperature': 60.71,
#      'dewPoint': 43.82,
#      'humidity': 0.54,
#      'pressure': 1014.3,
#      'windSpeed': 3.38,
#      'windGust': 5.74,
#      'windBearing': 158,
#      'cloudCover': 0.73,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 360.6},
#     {'time': 1619575200,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0.0014,
#      'precipProbability': 0.01,
#      'precipType': 'rain',
#      'temperature': 58.77,
#      'apparentTemperature': 58.77,
#      'dewPoint': 44.48,
#      'humidity': 0.59,
#      'pressure': 1014.3,
#      'windSpeed': 3.41,
#      'windGust': 6.58,
#      'windBearing': 170,
#      'cloudCover': 0.72,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 357.8},
#     {'time': 1619578800,
#      'summary': 'Mostly Cloudy',
#      'icon': 'partly-cloudy-night',
#      'precipIntensity': 0,
#      'precipProbability': 0,
#      'temperature': 57.26,
#      'apparentTemperature': 57.26,
#      'dewPoint': 45.83,
#      'humidity': 0.66,
#      'pressure': 1014,
#      'windSpeed': 3.45,
#      'windGust': 6.97,
#      'windBearing': 172,
#      'cloudCover': 0.63,
#      'uvIndex': 0,
#      'visibility': 10,
#      'ozone': 356.4}]},
#   'offset': -4}]

# %%
# FORMAT THE TEMPERATURE DATA TO VISUALIZE ON THE MAP
at_ts = {}
dt['hourly']['data']
# Out:
# [{'time': 1619496000,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 48.07,
#   'apparentTemperature': 47.46,
#   'dewPoint': 18.28,
#   'humidity': 0.3,
#   'pressure': 1019.6,
#   'windSpeed': 3.04,
#   'windGust': 17.2,
#   'windBearing': 333,
#   'cloudCover': 0.03,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 376.2},
#  {'time': 1619499600,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 46.49,
#   'apparentTemperature': 46.49,
#   'dewPoint': 18.61,
#   'humidity': 0.33,
#   'pressure': 1019.8,
#   'windSpeed': 2.75,
#   'windGust': 12.53,
#   'windBearing': 334,
#   'cloudCover': 0.02,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 376.1},
#  {'time': 1619503200,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 44.29,
#   'apparentTemperature': 42.58,
#   'dewPoint': 19.51,
#   'humidity': 0.37,
#   'pressure': 1019.7,
#   'windSpeed': 3.65,
#   'windGust': 7.88,
#   'windBearing': 326,
#   'cloudCover': 0.06,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 374.1},
#  {'time': 1619506800,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 43.75,
#   'apparentTemperature': 43.75,
#   'dewPoint': 22.01,
#   'humidity': 0.42,
#   'pressure': 1019.9,
#   'windSpeed': 2.05,
#   'windGust': 7.42,
#   'windBearing': 322,
#   'cloudCover': 0.39,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 372.2},
#  {'time': 1619510400,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 43.69,
#   'apparentTemperature': 42.24,
#   'dewPoint': 23.34,
#   'humidity': 0.44,
#   'pressure': 1020.3,
#   'windSpeed': 3.28,
#   'windGust': 7.65,
#   'windBearing': 279,
#   'cloudCover': 0.53,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 369.9},
#  {'time': 1619514000,
#   'summary': 'Overcast',
#   'icon': 'cloudy',
#   'precipIntensity': 0.0002,
#   'precipProbability': 0.03,
#   'precipType': 'rain',
#   'temperature': 43.67,
#   'apparentTemperature': 43.67,
#   'dewPoint': 26.42,
#   'humidity': 0.5,
#   'pressure': 1020.4,
#   'windSpeed': 2.24,
#   'windGust': 10.5,
#   'windBearing': 328,
#   'cloudCover': 0.88,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 369.5},
#  {'time': 1619517600,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 43.42,
#   'apparentTemperature': 43.42,
#   'dewPoint': 29.17,
#   'humidity': 0.57,
#   'pressure': 1020.5,
#   'windSpeed': 1.69,
#   'windGust': 8.49,
#   'windBearing': 344,
#   'cloudCover': 0.68,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 366.9},
#  {'time': 1619521200,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 43.87,
#   'apparentTemperature': 43.87,
#   'dewPoint': 29.35,
#   'humidity': 0.56,
#   'pressure': 1020.7,
#   'windSpeed': 1.17,
#   'windGust': 5.81,
#   'windBearing': 49,
#   'cloudCover': 0.59,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 366.2},
#  {'time': 1619524800,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0.0012,
#   'precipProbability': 0.12,
#   'precipType': 'rain',
#   'temperature': 47.1,
#   'apparentTemperature': 47.1,
#   'dewPoint': 25.63,
#   'humidity': 0.43,
#   'pressure': 1020.6,
#   'windSpeed': 1.01,
#   'windGust': 3.76,
#   'windBearing': 227,
#   'cloudCover': 0.21,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 366.5},
#  {'time': 1619528400,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 49.88,
#   'apparentTemperature': 49.88,
#   'dewPoint': 24.28,
#   'humidity': 0.36,
#   'pressure': 1020.7,
#   'windSpeed': 1.35,
#   'windGust': 3.68,
#   'windBearing': 198,
#   'cloudCover': 0.22,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 364.8},
#  {'time': 1619532000,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 52.4,
#   'apparentTemperature': 52.4,
#   'dewPoint': 23.72,
#   'humidity': 0.32,
#   'pressure': 1020,
#   'windSpeed': 2.21,
#   'windGust': 4.98,
#   'windBearing': 145,
#   'cloudCover': 0.3,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 363.8},
#  {'time': 1619535600,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.59,
#   'apparentTemperature': 55.59,
#   'dewPoint': 24.79,
#   'humidity': 0.3,
#   'pressure': 1019.2,
#   'windSpeed': 2.26,
#   'windGust': 5.12,
#   'windBearing': 156,
#   'cloudCover': 0.32,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 362.6},
#  {'time': 1619539200,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 58.64,
#   'apparentTemperature': 58.64,
#   'dewPoint': 23.67,
#   'humidity': 0.26,
#   'pressure': 1018.1,
#   'windSpeed': 4.32,
#   'windGust': 8.73,
#   'windBearing': 147,
#   'cloudCover': 0.63,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 361.8},
#  {'time': 1619542800,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 62.01,
#   'apparentTemperature': 62.01,
#   'dewPoint': 22.38,
#   'humidity': 0.22,
#   'pressure': 1017.1,
#   'windSpeed': 6.69,
#   'windGust': 9.57,
#   'windBearing': 177,
#   'cloudCover': 0.49,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 360.9},
#  {'time': 1619546400,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 63.5,
#   'apparentTemperature': 63.5,
#   'dewPoint': 26.05,
#   'humidity': 0.24,
#   'pressure': 1016.3,
#   'windSpeed': 7.31,
#   'windGust': 10.09,
#   'windBearing': 167,
#   'cloudCover': 0.22,
#   'uvIndex': 6,
#   'visibility': 10,
#   'ozone': 359.6},
#  {'time': 1619550000,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 65.76,
#   'apparentTemperature': 65.76,
#   'dewPoint': 25.62,
#   'humidity': 0.22,
#   'pressure': 1015.2,
#   'windSpeed': 4.28,
#   'windGust': 9.98,
#   'windBearing': 175,
#   'cloudCover': 0.08,
#   'uvIndex': 5,
#   'visibility': 10,
#   'ozone': 360.4},
#  {'time': 1619553600,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 68.08,
#   'apparentTemperature': 68.08,
#   'dewPoint': 28.5,
#   'humidity': 0.23,
#   'pressure': 1014.4,
#   'windSpeed': 3.63,
#   'windGust': 9.95,
#   'windBearing': 188,
#   'cloudCover': 0.22,
#   'uvIndex': 3,
#   'visibility': 10,
#   'ozone': 359.7},
#  {'time': 1619557200,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 69.28,
#   'apparentTemperature': 69.28,
#   'dewPoint': 31.07,
#   'humidity': 0.24,
#   'pressure': 1014.3,
#   'windSpeed': 3.2,
#   'windGust': 10.25,
#   'windBearing': 199,
#   'cloudCover': 0.54,
#   'uvIndex': 2,
#   'visibility': 10,
#   'ozone': 360.9},
#  {'time': 1619560800,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 70.15,
#   'apparentTemperature': 70.15,
#   'dewPoint': 35.99,
#   'humidity': 0.29,
#   'pressure': 1014.1,
#   'windSpeed': 4.27,
#   'windGust': 9.76,
#   'windBearing': 184,
#   'cloudCover': 0.37,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 362.4},
#  {'time': 1619564400,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 68.02,
#   'apparentTemperature': 68.02,
#   'dewPoint': 40.64,
#   'humidity': 0.37,
#   'pressure': 1014.1,
#   'windSpeed': 4.76,
#   'windGust': 7.86,
#   'windBearing': 175,
#   'cloudCover': 0.55,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 361.8},
#  {'time': 1619568000,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 63.58,
#   'apparentTemperature': 63.58,
#   'dewPoint': 42.77,
#   'humidity': 0.47,
#   'pressure': 1014.2,
#   'windSpeed': 3.93,
#   'windGust': 6.59,
#   'windBearing': 165,
#   'cloudCover': 0.7,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 361.7},
#  {'time': 1619571600,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 60.71,
#   'apparentTemperature': 60.71,
#   'dewPoint': 43.82,
#   'humidity': 0.54,
#   'pressure': 1014.3,
#   'windSpeed': 3.38,
#   'windGust': 5.74,
#   'windBearing': 158,
#   'cloudCover': 0.73,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 360.6},
#  {'time': 1619575200,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0014,
#   'precipProbability': 0.01,
#   'precipType': 'rain',
#   'temperature': 58.77,
#   'apparentTemperature': 58.77,
#   'dewPoint': 44.48,
#   'humidity': 0.59,
#   'pressure': 1014.3,
#   'windSpeed': 3.41,
#   'windGust': 6.58,
#   'windBearing': 170,
#   'cloudCover': 0.72,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 357.8},
#  {'time': 1619578800,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 57.26,
#   'apparentTemperature': 57.26,
#   'dewPoint': 45.83,
#   'humidity': 0.66,
#   'pressure': 1014,
#   'windSpeed': 3.45,
#   'windGust': 6.97,
#   'windBearing': 172,
#   'cloudCover': 0.63,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 356.4}]

# %%
# FORMAT ONE OF THE VARIABLES FOR VISUALIZATION (i.e. AIR TEMPERATURE)

at_ts = {}
for i in range(0, len(weather_arr)):
    for j in range(0,len(weather_arr[i]['hourly']['data'])):
        time_add = weather_arr[i]['hourly']['data'][j]['time']
        time_add = time.strftime('%Y-%m-%dT%H:%M:%S.000-04:00', time.localtime(time_add))
        temp_c = (weather_arr[i]['hourly']['data'][j]['temperature'] - 32) * (5/9)
        at_ts[time_add] = temp_c
at_ts
# Out:
# {'2021-04-20T00:00:00.000-04:00': 9.305555555555555,
#  '2021-04-20T01:00:00.000-04:00': 8.38888888888889,
#  '2021-04-20T02:00:00.000-04:00': 7.716666666666668,
#  '2021-04-20T03:00:00.000-04:00': 7.305555555555555,
#  '2021-04-20T04:00:00.000-04:00': 6.672222222222222,
#  '2021-04-20T05:00:00.000-04:00': 6.488888888888889,
#  '2021-04-20T06:00:00.000-04:00': 6.572222222222222,
#  '2021-04-20T07:00:00.000-04:00': 7.416666666666668,
#  '2021-04-20T08:00:00.000-04:00': 11.177777777777777,
#  '2021-04-20T09:00:00.000-04:00': 13.85,
#  '2021-04-20T10:00:00.000-04:00': 17.194444444444446,
#  '2021-04-20T11:00:00.000-04:00': 19.961111111111116,
#  '2021-04-20T12:00:00.000-04:00': 21.19444444444445,
#  '2021-04-20T13:00:00.000-04:00': 22.26111111111111,
#  '2021-04-20T14:00:00.000-04:00': 23.41666666666667,
#  '2021-04-20T15:00:00.000-04:00': 23.711111111111116,
#  '2021-04-20T16:00:00.000-04:00': 23.727777777777774,
#  '2021-04-20T17:00:00.000-04:00': 23.16111111111111,
#  '2021-04-20T18:00:00.000-04:00': 23.35,
#  '2021-04-20T19:00:00.000-04:00': 22.277777777777775,
#  '2021-04-26T23:00:00.000-04:00': 9.95,
#  '2021-04-27T00:00:00.000-04:00': 8.927777777777779,
#  '2021-04-27T01:00:00.000-04:00': 8.05,
#  '2021-04-27T02:00:00.000-04:00': 6.8277777777777775,
#  '2021-04-27T03:00:00.000-04:00': 6.527777777777778,
#  '2021-04-27T04:00:00.000-04:00': 6.494444444444444,
#  '2021-04-27T05:00:00.000-04:00': 6.483333333333334,
#  '2021-04-27T06:00:00.000-04:00': 6.344444444444446,
#  '2021-04-27T07:00:00.000-04:00': 6.594444444444443,
#  '2021-04-27T08:00:00.000-04:00': 8.38888888888889,
#  '2021-04-27T09:00:00.000-04:00': 9.933333333333335,
#  '2021-04-27T10:00:00.000-04:00': 11.333333333333334,
#  '2021-04-27T11:00:00.000-04:00': 13.105555555555558,
#  '2021-04-27T12:00:00.000-04:00': 14.8,
#  '2021-04-27T13:00:00.000-04:00': 16.67222222222222,
#  '2021-04-27T14:00:00.000-04:00': 17.5,
#  '2021-04-27T15:00:00.000-04:00': 18.75555555555556,
#  '2021-04-27T16:00:00.000-04:00': 20.044444444444444,
#  '2021-04-27T17:00:00.000-04:00': 20.711111111111112,
#  '2021-04-27T18:00:00.000-04:00': 21.19444444444445,
#  '2021-04-27T19:00:00.000-04:00': 20.01111111111111,
#  '2021-04-27T20:00:00.000-04:00': 17.544444444444444,
#  '2021-04-27T21:00:00.000-04:00': 15.950000000000001,
#  '2021-04-27T22:00:00.000-04:00': 14.872222222222225,
#  '2021-04-27T23:00:00.000-04:00': 14.033333333333333}

# %%
# GET FORECAST OF METEOROLOGICAL DATA

# For next 168 hours
# urlt = "https://api.darksky.net/forecast/{}/{},{}?extend=hourly?exclude=currently,minutely,daily,alerts,flags".format(ds_key, locationt[0], locationt[1])

# For next 48 hours
url_fc = "https://api.darksky.net/forecast/{}/{},{}?exclude=currently,minutely,daily,alerts,flags".format(ds_key, locationt[0], locationt[1])

response_fc = requests.request("GET", url_fc)

dt_fc = eval(response_fc.text)

# %%
# FORMAT THE FORCAST INTO THE HISTORICAL ARRAY
at_ts_fc = {}
for i in range(0, len(dt_fc['hourly']['data'])):
    for j in range(0,len(dt_fc['hourly']['data'])):
        time_add = dt_fc['hourly']['data'][j]['time']
        time_add = time.strftime('%Y-%m-%dT%H:%M:%S.000-04:00', time.localtime(time_add))
        temp_c = (dt_fc['hourly']['data'][j]['temperature'] - 32) * (5/9)
        at_ts_fc[time_add] = temp_c

# GET RID OF ANY OVERLAPPING DATA
hours_since_mn = int(seconds_since_midnight / 60 / 60)
hours_to_mn = 23 - hours_since_mn

for i in range(0,hours_to_mn):
    at_ts_fc.pop(next(iter(at_ts_fc)))

## APPEND THE FORECAST DATA TO THE ARRAY
at_ts.update(at_ts_fc)

at_ts
# Out:
# {'2021-04-20T00:00:00.000-04:00': 9.305555555555555,
#  '2021-04-20T01:00:00.000-04:00': 8.38888888888889,
#  '2021-04-20T02:00:00.000-04:00': 7.716666666666668,
#  '2021-04-20T03:00:00.000-04:00': 7.305555555555555,
#  '2021-04-20T04:00:00.000-04:00': 6.672222222222222,
#  '2021-04-28T09:00:00.000-04:00': 19.227777777777778,
#  '2021-04-28T10:00:00.000-04:00': 22.461111111111116,
#  '2021-04-28T11:00:00.000-04:00': 25.333333333333332,
#  '2021-04-28T12:00:00.000-04:00': 27.094444444444445,
#  '2021-04-28T13:00:00.000-04:00': 28.588888888888885,
#  '2021-04-28T14:00:00.000-04:00': 29.255555555555556,
#  '2021-04-28T15:00:00.000-04:00': 30.0,
#  '2021-04-28T16:00:00.000-04:00': 29.61666666666667,
#  '2021-04-28T17:00:00.000-04:00': 29.044444444444448,
#  '2021-04-28T18:00:00.000-04:00': 28.150000000000002,
#  '2021-04-28T19:00:00.000-04:00': 26.944444444444446,
#  '2021-04-28T20:00:00.000-04:00': 25.433333333333334,
#  '2021-04-28T21:00:00.000-04:00': 24.466666666666672,
#  '2021-04-28T22:00:00.000-04:00': 23.800000000000004,
#  '2021-04-28T23:00:00.000-04:00': 23.277777777777782,
#  '2021-04-29T00:00:00.000-04:00': 22.333333333333336,
#  '2021-04-29T01:00:00.000-04:00': 21.661111111111108,
#  '2021-04-29T02:00:00.000-04:00': 21.005555555555556,
#  '2021-04-29T03:00:00.000-04:00': 20.366666666666667,
#  '2021-04-29T04:00:00.000-04:00': 19.777777777777775,
#  '2021-04-29T05:00:00.000-04:00': 19.34444444444444,
#  '2021-04-29T06:00:00.000-04:00': 18.988888888888894,
#  '2021-04-29T07:00:00.000-04:00': 18.833333333333336,
#  '2021-04-29T08:00:00.000-04:00': 19.138888888888893,
#  '2021-04-29T09:00:00.000-04:00': 19.81111111111111,
#  '2021-04-29T10:00:00.000-04:00': 20.65555555555556,
#  '2021-04-29T11:00:00.000-04:00': 21.40555555555556,
#  '2021-04-29T12:00:00.000-04:00': 21.816666666666666,
#  '2021-04-29T13:00:00.000-04:00': 21.90555555555556,
#  '2021-04-29T14:00:00.000-04:00': 22.083333333333336,
#  '2021-04-29T15:00:00.000-04:00': 22.12222222222222,
#  '2021-04-29T16:00:00.000-04:00': 21.622222222222224}

# %%
# DISPLAY RESULTS

plt.figure(figsize = (18,9))
plt.plot(at_ts.keys(), at_ts.values(), linewidth=1, color='darkred', label="Air Temperature")
plt.plot(wt_ts.keys(), wt_ts.values(), linewidth=1, color='navy', label="Stream Temperature")
# PUT FORECASTED TEMPERATURE HERE
plt.grid(color='grey')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(0,len(at_ts),12),rotation=90, fontsize=16)
plt.title('USGS Stream Gauge {} ({}, {})'.format(gage, round(y,7), round(x,7)), fontsize=18)
plt.xlabel('',fontsize=16)
plt.ylabel('Temperature, C',fontsize=16)
#plt.savefig('timeseries_temperature.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## FROM HERE SEND ALL DATA TO WT MODEL AND GET FORECAST
# {'time': 1619150400,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 40.21,
#   'apparentTemperature': 37.32,
#   'dewPoint': 19.47,
#   'humidity': 0.43,
#   'pressure': 1014.8,
#   'windSpeed': 4.27,
#   'windGust': 23.5,
#   'windBearing': 276,
#   'cloudCover': 0.27,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 458.3}
